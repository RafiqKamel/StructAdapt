# %%
from convert_AMR import create_dataloader, convert_AMR
from litgpt.model import GPT
import numpy as np
import torch
import networkx as nx
from litgpt.config import Config
import matplotlib.pyplot as plt
import random
import itertools
from io import StringIO
# Out:
# 2024-08-16 16:33:32 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX

# %%
def magnetic_laplacian(g, q = 0.25, tolerance = 1e-10):
    def exp_theta_i(A, q=0.25):
        return np.exp(2 * np.pi * q * 1j*(A - A.T))
    A_symmetric = nx.adjacency_matrix(g.to_undirected()).toarray()
    A_directed = nx.adjacency_matrix(g).toarray()
    D_s = np.diag(np.sum(A_symmetric, axis=1))
    asymmetric_element = exp_theta_i(A_directed, q)
    laplacian = D_s - np.multiply(asymmetric_element, A_symmetric)
    
    # Check if the real part is very close to zero and set it to zero
    laplacian_real = np.real(laplacian)
    laplacian_real[np.abs(laplacian_real) < tolerance] = 0
    # Reconstruct the complex array with the updated real part and original imaginary part
    laplacian = laplacian_real + 1j * laplacian.imag
    return laplacian

def convert_complex_to_real(eig_vecs):
    """
    Convert complex eigenvectors to real by concatenating the real and imaginary parts.

    Parameters:
    eig_vecs (numpy.ndarray): Complex eigenvectors.

    Returns:
    numpy.ndarray: Real-valued vectors.
    """
    real_part = np.real(eig_vecs)
    imag_part = np.imag(eig_vecs)
    real_valued_vecs = np.concatenate((real_part, imag_part), axis=-1)
    return real_valued_vecs

def magL_eigenvalues(MagL):
    eigvals, eig_vecs = np.linalg.eig(MagL)
    return convert_complex_to_real(eig_vecs)

# %%
import torch

def pad_1d_tensor(tensor, target_length, pad_value=0):
    """
    Pads the input 1D tensor to the target length with the specified pad value.
    
    Args:
    tensor (torch.Tensor): The input 1D tensor to pad.
    target_length (int): The target length.
    pad_value (float): The value to use for padding.
    
    Returns:
    torch.Tensor: The padded 1D tensor.
    """
    pad_length = target_length - tensor.size(0)
    return torch.nn.functional.pad(tensor, (0, pad_length), 'constant', pad_value)

def list_of_lists_to_3d_tensor(list_of_lists, pad_value=0):
    """
    Converts a list of list of 1D tensors into a 3D tensor by padding the smaller tensors.
    
    Args:
    list_of_lists (list of list of torch.Tensor): The input list of lists of 1D tensors.
    pad_value (float): The value to use for padding.
    
    Returns:
    torch.Tensor: The resulting 3D tensor.
    """
    # Flatten the list of lists and determine the max length
    all_tensors = [tensor for sublist in list_of_lists for tensor in sublist]
    max_length = max(tensor.size(0) for tensor in all_tensors)
    
    # Pad each 1D tensor and gather them in a list
    padded_tensors = [[pad_1d_tensor(tensor, max_length, pad_value) for tensor in sublist] for sublist in list_of_lists]
    
    # Stack the padded tensors to form a 3D tensor
    stacked_tensor = [torch.stack(sublist) if len(sublist)>0 else torch.tensor([]) for sublist in padded_tensors]
    stacked_tensor = torch.stack(stacked_tensor)
    
    return stacked_tensor
import torch

def pad_1d_tensor(tensor, target_length, pad_value=0):
    """
    Pads the input 1D tensor to the target length with the specified pad value.
    
    Args:
    tensor (torch.Tensor): The input 1D tensor to pad.
    target_length (int): The target length.
    pad_value (float): The value to use for padding.
    
    Returns:
    torch.Tensor: The padded 1D tensor.
    """
    pad_length = target_length - tensor.size(0)
    return torch.nn.functional.pad(tensor, (0, pad_length), 'constant', pad_value)

def pad_list_of_tensors(lists, target_length, max_length, pad_value):
    """
    Pads the list of tensors to the target length with tensors filled with the pad value.
    
    Args:
    lists (list of torch.Tensor): The input list to pad.
    target_length (int): The target length.
    max_length (int): The maximum length of the 1D tensors.
    pad_value (float): The value to use for padding.
    
    Returns:
    list of torch.Tensor: The padded list.
    """
    padded_tensor = torch.tensor([pad_value] * max_length)
    padded_list = lists + [padded_tensor] * (target_length - len(lists))
    return padded_list

def list_of_lists_to_4d_tensor(list_of_lists, pad_value=0):
    """
    Converts a list of list of list of 1D tensors into a 4D tensor by padding the smaller tensors
    and lists.
    
    Args:
    list_of_lists (list of list of list of torch.Tensor): The input list of lists of lists of 1D tensors.
    pad_value (float): The value to use for padding.
    
    Returns:
    torch.Tensor: The resulting 4D tensor.
    """
    # Flatten the 3-layer list and determine the max length and sizes
    all_tensors = [tensor for lvl1 in list_of_lists for lvl2 in lvl1 for tensor in lvl2]
    max_length = max(tensor.size(0) for tensor in all_tensors)
    max_lvl2_length = max(len(lvl2) for lvl1 in list_of_lists for lvl2 in lvl1)
    max_lvl1_length = max(len(lvl1) for lvl1 in list_of_lists)
    max_lvl0_length = len(list_of_lists)
    
    # Pad each 1D tensor and reconstruct the 3-layer structure
    padded_tensors = [[[pad_1d_tensor(tensor, max_length, pad_value) for tensor in lvl2] for lvl2 in lvl1] for lvl1 in list_of_lists]

    # Pad the inner lists to the maximum level 2 length
    padded_tensors = [[pad_list_of_tensors(lvl2, max_lvl2_length, max_length, pad_value) for lvl2 in lvl1] for lvl1 in padded_tensors]

    # Pad the level 1 lists to the maximum level 1 length
    padded_tensors = [pad_list_of_tensors(lvl1, max_lvl1_length, max_length, pad_value) for lvl1 in padded_tensors]

    # Pad the outermost list to the maximum level 0 length
    padded_tensors = pad_list_of_tensors(padded_tensors, max_lvl0_length, max_length, pad_value)

    # Separate the stacking operations
    stacked_lvl3 = [[torch.stack(lvl3) for lvl3 in lvl2] for lvl2 in padded_tensors]
    stacked_lvl2 = [torch.stack(lvl2) for lvl2 in stacked_lvl3]
    stacked_lvl1 = torch.stack(stacked_lvl2)

    return stacked_lvl1


def tensor_of_tensors_to_list_of_lists(tensor):
    return tensor.tolist()

# %%
import json
path = "./data/amr3/processed_amr"
dl, tokenizer = create_dataloader(path, batch_size=128)

# Initialize the dictionary to store batches
batches_dict = {
    "node_ids": [],
    "eig_vecs": [],
    "node_labels": [],
    "graphs": [],
    "target_labels": [],
    "graph_text": [],   
}
c = 0
for batch in dl:
    node_ids_batch = []
    edge_index_batch = []
    eig_vecs_batch = []
    node_labels_batch = []
    graphs_batch = []
    labels_batch = []
    graph_text_batch = []
    if c==2:
        #break
        pass

    for i in range(len(batch["input_ids"])):
        tgt_labels = batch["labels"][i]
        edges, edge_type = batch["graphs"][i]
        input_ids = batch["input_ids"][i]
        target_text = batch["tgt_text"][i]
        source_text = batch["src_text"][i]
        AMR = convert_AMR(input_ids=input_ids, edges=edges, edge_types=edge_type, target_labels=tgt_labels, tokenizer=tokenizer, target_text=target_text)
        # Prepare graph input
        G = AMR["graph"]
        
        if G.number_of_nodes() == 0:
            continue
        node_labels = AMR["node_labels"]
        # MagL = magnetic_laplacian(G, q=0.25)
        # eig_vecs = magL_eigenvalues(MagL)

        # Get the edge list
        edge_list = nx.generate_edgelist(G, data=False)

        # Convert edge list to a single string
        edge_list_str = "\n".join(edge_list)

        
        node_ids_batch.append(torch.tensor(list(AMR["node_labels"].keys())))
        # eig_vecs_batch.append(torch.tensor(eig_vecs))
        node_labels_batch.append(torch.tensor(AMR["input_ids"]))
        graphs_batch.append(G)
        labels_batch.append(AMR["target_text"])
        graph_text_batch.append(edge_list_str)
        sentence = tokenizer.decode(input_ids)
        if(len(sentence.split()) != len(G.nodes())):
            if source_text != len(G.nodes()):
                print("ERROR")
                print(sentence)
                print(source_text)
                for n in sorted(G.nodes()):

                    print(n, AMR["node_labels"][n])
    
    batch_dict = {}    
    for i in range(len(node_labels_batch)):
        batch_dict[i] = {
            "node_ids": node_ids_batch[i].tolist(),
            # "eig_vecs": list(eig_vecs_batch[i]),
            "node_labels": tokenizer.decode(node_labels_batch[i]),
            "target_labels": labels_batch[i],
            "graph_text": graph_text_batch[i],
        }
    # Specify the file path to save the JSON file
    file_path = f"./custom_datasets_batches/{c}.json"

    # Convert batch_dict to JSON format
    batch_dict_json = json.dumps(batch_dict)

    # Write the JSON data to the file
    with open(file_path, 'w') as file:
        file.write(batch_dict_json)
        
    # Append the processed batch to the dictionary
    batches_dict["node_ids"].append(node_ids_batch)
    # batches_dict["eig_vecs"].append(eig_vecs_batch)
    batches_dict["node_labels"].append(node_labels_batch)
    batches_dict["graphs"].append(graphs_batch)
    batches_dict["target_labels"].append(labels_batch)
    batches_dict["graph_text"].append(graph_text_batch)
    c += 1

# batches_dict["node_labels"] = list_of_lists_to_3d_tensor(batches_dict["node_labels"], pad_value=tokenizer.pad_token_id)
# batches_dict["eig_vecs"] = list_of_lists_to_4d_tensor(batches_dict["eig_vecs"], pad_value=0)
# Out:
# Added 165 tokens
# ERROR
# and :op1 believe :ARG0 person :ARG0-of have-org-role :ARG1 company :wiki - :name name :op1 IM :mod country :wiki United_States :name name :op1 United :op2 States :ARG2 officer :mod executive :mod chief :ARG1 capable :ARG1 person :ARG1-of employ :ARG0 company :mod each :ARG2 innovate :ARG0 person :op2 formulate :ARG0 officer :mod executive :mod chief :ARG1 countermeasure :mod strategy :purpose innovate :topic industry :time after :op1 invent :ARG0 company :ARG0-of compete :ARG1 company :ARG1 machine :ARG0-of wash :ARG1-of load :mod front
# and :op1 believe :ARG0 person :ARG0-of have-org-role :ARG1 company :wiki - :name name :op1 IM :mod country :wiki United_States :name name :op1 United :op2 States :ARG2 officer :mod executive :mod chief :ARG1 capable :ARG1 person :ARG1-of employ :ARG0 company :mod each :ARG2 innovate :ARG0 person :op2 formulate :ARG0 officer :mod executive :mod chief :ARG1 countermeasure :mod strategy :purpose innovate :topic industry :time after :op1 invent :ARG0 company :ARG0-of compete :ARG1 company :ARG1 machine :ARG0-of wash :ARG1-of load :mod front
# 0 and
# 1 :op1
# 2 believe
# 3 :ARG0
# 4 person
# 5 :ARG0-of
# 6 have
# 7 -
# 8 org
# 9 -
# 10 rol
# 11 e
# 12 :ARG1
# 13 company
# 17 :name
# 18 name
# 19 :op1
# 20
# 21 IM
# 22 :mod
# 23 country
# 30 :name
# 31 name
# 32 :op1
# 33 United
# 34 :op2
# 35 States
# 36 :ARG2
# 37 officer
# 38 :mod
# 39 executive
# 40 :mod
# 41 chief
# 42 :ARG1
# 43 capable
# 44 :ARG1
# 45 person
# 46 :ARG1-of
# 47 employ
# 48 :ARG0
# 49 company
# 50 :mod
# 51 each
# 52 :ARG2
# 53 innovate
# 54 :ARG0
# 55 person
# 56 :op2
# 57 formulate
# 58 :ARG0
# 59 officer
# 60 :mod
# 61 executive
# 62 :mod
# 63 chief
# 64 :ARG1
# 65 counter
# 66 measure
# 67 :mod
# 68 strategy
# 69 :purpose
# 70 innovate
# 71 :topic
# 72 industry
# 73 :time
# 74 after
# 75 :op1
# 76 in
# 77 vent
# 78 :ARG0
# 79 company
# 80 :ARG0-of
# 81 compete
# 82 :ARG1
# 83 company
# 84 :ARG1
# 85 machine
# 86 :ARG0-of
# 87 wash
# 88 :ARG1-of
# 89 load
# 90 :mod
# 91 front
# ERROR
# establish :li 1 :ARG1 fund :purpose innovate :ARG1-of amount :ARG2 at-most :op1 monetary-quantity :quant 1000 :unit dollar :mod country :wiki United_States :name name :op1 United :op2 States
# establish :li 1 :ARG1 fund :purpose innovate :ARG1-of amount :ARG2 at-most :op1 monetary-quantity :quant 1000 :unit dollar :mod country :wiki United_States :name name :op1 United :op2 States
# 0 establish
# 1 :li
# 2 1
# 3 :ARG1
# 4 fund
# 5 :purpose
# 6 innovate
# 7 :ARG1-of
# 8 amount
# 9 :ARG2
# 10 at
# 11 -
# 12 most
# 13 :op1
# 14
# 15 monetary
# 16 -
# 17 quant
# 18 ity
# 19 :quant
# 20 1000
# 21 :unit
# 22 dollar
# 23 :mod
# 24 country
# 31 :name
# 32 name
# 33 :op1
# 34 United
# 35 :op2
# 36 States
# ERROR
# pick-out :li 3 :ARG1 thing :quant 50 :ARG1-of submit :ARG2 committee :ARG0-of assess :ARG3 assess :ARG0 committee :ARG1 thing :ARG2 they
# pick-out :li 3 :ARG1 thing :quant 50 :ARG1-of submit :ARG2 committee :ARG0-of assess :ARG3 assess :ARG0 committee :ARG1 thing :ARG2 they
# 0 pick
# 1 -
# 2 out
# 3 :li
# 4 3
# 5 :ARG1
# 6 thing
# 7 :quant
# 8 50
# 9 :ARG1-of
# 10 submit
# 11 :ARG2
# 12 committee
# 13 :ARG0-of
# 14 assess
# 15 :ARG3
# 16 assess
# 17 :ARG0
# 18 committee
# 19 :ARG1
# 20 thing
# 21 :ARG2
# 22 they
# ERROR
# point :mod start :ARG1 standard :mod construct :location mainland :domain recommend :ARG1 preserve :ARG0 building :ARG1 frame :part-of thing :mod basic :poss building :manner collapse :polarity - :ARG1 frame :time since :op1 earthquake :wiki 1976_Tangshan_earthquake :name name :op1 Tangshan :condition earthquake :mod magnitude :ARG1-of same :ARG2 magnitude :poss earthquake
# point :mod start :ARG1 standard :mod construct :location mainland :domain recommend :ARG1 preserve :ARG0 building :ARG1 frame :part-of thing :mod basic :poss building :manner collapse :polarity - :ARG1 frame :time since :op1 earthquake :wiki 1976_Tangshan_earthquake :name name :op1 Tangshan :condition earthquake :mod magnitude :ARG1-of same :ARG2 magnitude :poss earthquake
# 0 point
# 1 :mod
# 2 start
# 3 :ARG1
# 4 standard
# 5 :mod
# 6 construct
# 7 :location
# 8 mainland
# 9 :domain
# 10 recommend
# 11 :ARG1
# 12 preserve
# 13 :ARG0
# 14 building
# 15 :ARG1
# 16 frame
# 17 :part-of
# 18 thing
# 19 :mod
# 20 basic
# 21 :poss
# 22 building
# 23 :manner
# 24 collapse
# 25 :polarity
# 26
# 27 -
# 28 :ARG1
# 29 frame
# 30 :time
# 31 since
# 32 :op1
# 33 earthquake
# 46 :name
# 47 name
# 48 :op1
# 49 Tang
# 50 s
# 51 han
# 52 :condition
# 53 earthquake
# 54 :mod
# 55 magnitude
# 56 :ARG1-of
# 57 same
# 58 :ARG2
# 59 magnitude
# 60 :poss
# 61 earthquake
# ERROR
# contrast :ARG2 and :op1 meet :polarity - :ARG0 building :quant most :ARG1-of include :ARG2 building :location area :ARG1-of hit :ARG1-of hard :mod this :ARG1 thing :ARG1-of require :mod this :op2 arouse :ARG0 collapse :ARG1 building :mod school :ARG1-of spread :ARG1-of wide :ARG1 disgust :ARG1 public :ARG1-of intense :mod particular
# contrast :ARG2 and :op1 meet :polarity - :ARG0 building :quant most :ARG1-of include :ARG2 building :location area :ARG1-of hit :ARG1-of hard :mod this :ARG1 thing :ARG1-of require :mod this :op2 arouse :ARG0 collapse :ARG1 building :mod school :ARG1-of spread :ARG1-of wide :ARG1 disgust :ARG1 public :ARG1-of intense :mod particular
# 0 contrast
# 1 :ARG2
# 2 and
# 3 :op1
# 4 meet
# 5 :polarity
# 6
# 7 -
# 8 :ARG0
# 9 building
# 10 :quant
# 11 most
# 12 :ARG1-of
# 13 include
# 14 :ARG2
# 15 building
# 16 :location
# 17 area
# 18 :ARG1-of
# 19 hit
# 20 :ARG1-of
# 21 hard
# 22 :mod
# 23 this
# 24 :ARG1
# 25 thing
# 26 :ARG1-of
# 27 require
# 28 :mod
# 29 this
# 30 :op2
# 31
# 32 a
# 33 rous
# 34 e
# 35 :ARG0
# 36 collapse
# 37 :ARG1
# 38 building
# 39 :mod
# 40 school
# 41 :ARG1-of
# 42 spread
# 43 :ARG1-of
# 44 wide
# 45 :ARG1
# 46 disgust
# 47 :ARG1
# 48 public
# 49 :ARG1-of
# 50 intense
# 51 :mod
# 52 particular
# ERROR
# possible :ARG1 and :op1 leave :ARG0 raise :ARG1 standard :ARG4 in-excess-of :op1 seismic-quantity :quant 8.0 :poss earthquake :wiki 1976_Tangshan_earthquake :name name :op1 Tangshan :ARG1 have :ARG0 authority :ARG1 space :mod breathe :quant some :purpose explain :ARG0 authority :op2 alleviate :ARG0 raise-01 :ARG1 anger :ARG1 public
# possible :ARG1 and :op1 leave :ARG0 raise :ARG1 standard :ARG4 in-excess-of :op1 seismic-quantity :quant 8.0 :poss earthquake :wiki 1976_Tangshan_earthquake :name name :op1 Tangshan :ARG1 have :ARG0 authority :ARG1 space :mod breathe :quant some :purpose explain :ARG0 authority :op2 alleviate :ARG0 raise-01 :ARG1 anger :ARG1 public
# 0 possible
# 1 :ARG1
# 2 and
# 3 :op1
# 4 leave
# 5 :ARG0
# 6 raise
# 7 :ARG1
# 8 standard
# 9 :ARG4
# 10 in
# 11 -
# 12 ex
# 13 ces
# 14 s
# 15 -
# 16 of
# 17 :op1
# 18 seismic
# 19 -
# 20 quant
# 21 ity
# 22 :quant
# 23
# 24 8.0
# 25 :poss
# 26 earthquake
# 39 :name
# 40 name
# 41 :op1
# 42 Tang
# 43 s
# 44 han
# 45 :ARG1
# 46 have
# 47 :ARG0
# 48 authority
# 49 :ARG1
# 50 space
# 51 :mod
# 52 breathe
# 53 :quant
# 54 some
# 55 :purpose
# 56 explain
# 57 :ARG0
# 58 authority
# 59 :op2
# 60 alleviat
# 61 e
# 62 :ARG0
# 63 raise
# 64 -01
# 65 :ARG1
# 66 anger
# 67 :ARG1
# 68 public
# ERROR
# say :ARG0 information :ARG1-of leak :ARG0 channel :quant numerous :ARG1 possible :ARG1 say :ARG0 we :ARG1 know :ARG0 political-party :wiki Communist_Party_of_China :name name :op1 CCP :ARG1 risk :ARG2 earthquake :ARG1-of serious :location local-region :wiki Ngawa_Tibetan_and_Qiang_Autonomous_Prefecture :name name :op1 Ngawa :time before :op1 strike :ARG2 earthquake :time already :ARG1-of well :manner certain
# say :ARG0 information :ARG1-of leak :ARG0 channel :quant numerous :ARG1 possible :ARG1 say :ARG0 we :ARG1 know :ARG0 political-party :wiki Communist_Party_of_China :name name :op1 CCP :ARG1 risk :ARG2 earthquake :ARG1-of serious :location local-region :wiki Ngawa_Tibetan_and_Qiang_Autonomous_Prefecture :name name :op1 Ngawa :time before :op1 strike :ARG2 earthquake :time already :ARG1-of well :manner certain
# 0 say
# 1 :ARG0
# 2 information
# 3 :ARG1-of
# 4 leak
# 5 :ARG0
# 6 channel
# 7 :quant
# 8 numerous
# 9 :ARG1
# 10 possible
# 11 :ARG1
# 12 say
# 13 :ARG0
# 14 we
# 15 :ARG1
# 16 know
# 17 :ARG0
# 18 political
# 19 -
# 20 party
# 30 :name
# 31 name
# 32 :op1
# 33 C
# 34 CP
# 35 :ARG1
# 36 risk
# 37 :ARG2
# 38 earthquake
# 39 :ARG1-of
# 40 serious
# 41 :location
# 42 local
# 43 -
# 44 region
# 69 :name
# 70 name
# 71 :op1
# 72 N
# 73 g
# 74 awa
# 75 :time
# 76 before
# 77 :op1
# 78 strike
# 79 :ARG2
# 80 earthquake
# 81 :time
# 82 already
# 83 :ARG1-of
# 84 well
# 85 :manner
# 86 certain
# ERROR
# have-concession :ARG1 accumulate :ARG1 experience :quant considerable :topic and :op1 predict :extent temporal-quantity :quant 1 :unit month :op2 predict :ARG1 area :part-of province :location and :op1 country :wiki China :name name :op1 China :op2 overseas :ARG2 possible :polarity - :ARG1 predict :ARG0 standard :mod forecast :time current :ARG1 and :op1 time :time-of earthquake :op2 place :location-of earthquake :op3 strong :ARG1 earthquake :mod exact :mod accurate :beneficiary we
# have-concession :ARG1 accumulate :ARG1 experience :quant considerable :topic and :op1 predict :extent temporal-quantity :quant 1 :unit month :op2 predict :ARG1 area :part-of province :location and :op1 country :wiki China :name name :op1 China :op2 overseas :ARG2 possible :polarity - :ARG1 predict :ARG0 standard :mod forecast :time current :ARG1 and :op1 time :time-of earthquake :op2 place :location-of earthquake :op3 strong :ARG1 earthquake :mod exact :mod accurate :beneficiary we
# 0 have
# 1 -
# 2 con
# 3 cession
# 4 :ARG1
# 5 accumulate
# 6 :ARG1
# 7 experience
# 8 :quant
# 9 considerable
# 10 :topic
# 11 and
# 12 :op1
# 13 predict
# 14 :extent
# 15 temp
# 16 oral
# 17 -
# 18 quant
# 19 ity
# 20 :quant
# 21 1
# 22 :unit
# 23 month
# 24 :op2
# 25 predict
# 26 :ARG1
# 27 area
# 28 :part-of
# 29 province
# 30 :location
# 31 and
# 32 :op1
# 33 country
# 35 China
# 36 :name
# 37 name
# 38 :op1
# 39 China
# 40 :op2
# 41 overseas
# 42 :ARG2
# 43 possible
# 44 :polarity
# 45
# 46 -
# 47 :ARG1
# 48 predict
# 49 :ARG0
# 50 standard
# 51 :mod
# 52 forecast
# 53 :time
# 54 current
# 55 :ARG1
# 56 and
# 57 :op1
# 58 time
# 59 :time-of
# 60 earthquake
# 61 :op2
# 62 place
# 63 :location-of
# 64 earthquake
# 65 :op3
# 66 strong
# 67 :ARG1
# 68 earthquake
# 69 :mod
# 70 exact
# 71 :mod
# 72 accurate
# 73 :beneficiary
# 74 we
# ERROR
# multi-sentence :snt1 possible :ARG1 reduce :ARG0 and :op1 warn :ARG2 public :op2 spread :ARG1 awareness :topic prevent :ARG1 disaster :ARG1 casualty :location region :location-of high :ARG1 risk :ARG2 earthquake :extent great :time earthquake :snt2 duty :domain this :mod minimum :degree very :ARG1-of undertake :ARG0 government-organization :ARG0-of govern :ARG1-of responsible :mod any :ARG1-of recommend
# multi-sentence :snt1 possible :ARG1 reduce :ARG0 and :op1 warn :ARG2 public :op2 spread :ARG1 awareness :topic prevent :ARG1 disaster :ARG1 casualty :location region :location-of high :ARG1 risk :ARG2 earthquake :extent great :time earthquake :snt2 duty :domain this :mod minimum :degree very :ARG1-of undertake :ARG0 government-organization :ARG0-of govern :ARG1-of responsible :mod any :ARG1-of recommend
# 0 multi
# 1 -
# 2 sent
# 3 ence
# 4 :snt1
# 5 possible
# 6 :ARG1
# 7 reduce
# 8 :ARG0
# 9 and
# 10 :op1
# 11 warn
# 12 :ARG2
# 13 public
# 14 :op2
# 15 spread
# 16 :ARG1
# 17 awareness
# 18 :topic
# 19 prevent
# 20 :ARG1
# 21 disaster
# 22 :ARG1
# 23 casual
# 24 t
# 25 y
# 26 :location
# 27 region
# 28 :location-of
# 29 high
# 30 :ARG1
# 31 risk
# 32 :ARG2
# 33 earthquake
# 34 :extent
# 35 great
# 36 :time
# 37 earthquake
# 38 :snt2
# 39 duty
# 40 :domain
# 41 this
# 42 :mod
# 43 minimum
# 44 :degree
# 45 very
# 46 :ARG1-of
# 47 undertake
# 48 :ARG0
# 49 government
# 50 -
# 51 organiz
# 52 ation
# 53 :ARG0-of
# 54 govern
# 55 :ARG1-of
# 56 responsible
# 57 :mod
# 58 any
# 59 :ARG1-of
# 60 recommend
# ERROR
# have-concession :ARG1 and :op1 do :ARG0 political-party :ARG1 nothing :mod only :polarity - :op2 respond :ARG0 political-party :ARG1 thing :ARG2-of query :ARG0 public :ARG2 and :op1 pull :ARG0 political-party :ARG1 thing :ARG1-of lie :quant some :mod whopping :ARG2 out :op2 play :ARG0 political-party :ARG1 game :mod syntax :ARG2 word :example and :op1 disaster :mod geology :op2 disaster :mod earthquake :time thing :ARG1-of occasion :mod this :ARG2 do :ARG0 political-party :wiki Communist_Party_of_China :name name :op1 CCP :ARG1 thing :quant lot :mod sort :mod this :time past
# have-concession :ARG1 and :op1 do :ARG0 political-party :ARG1 nothing :mod only :polarity - :op2 respond :ARG0 political-party :ARG1 thing :ARG2-of query :ARG0 public :ARG2 and :op1 pull :ARG0 political-party :ARG1 thing :ARG1-of lie :quant some :mod whopping :ARG2 out :op2 play :ARG0 political-party :ARG1 game :mod syntax :ARG2 word :example and :op1 disaster :mod geology :op2 disaster :mod earthquake :time thing :ARG1-of occasion :mod this :ARG2 do :ARG0 political-party :wiki Communist_Party_of_China :name name :op1 CCP :ARG1 thing :quant lot :mod sort :mod this :time past
# 0 have
# 1 -
# 2 con
# 3 cession
# 4 :ARG1
# 5 and
# 6 :op1
# 7 do
# 8 :ARG0
# 9 political
# 10 -
# 11 party
# 12 :ARG1
# 13 nothing
# 14 :mod
# 15 only
# 16 :polarity
# 17
# 18 -
# 19 :op2
# 20 respond
# 21 :ARG0
# 22 political
# 23 -
# 24 party
# 25 :ARG1
# 26 thing
# 27 :ARG2-of
# 28 query
# 29 :ARG0
# 30 public
# 31 :ARG2
# 32 and
# 33 :op1
# 34 pull
# 35 :ARG0
# 36 political
# 37 -
# 38 party
# 39 :ARG1
# 40 thing
# 41 :ARG1-of
# 42 lie
# 43 :quant
# 44 some
# 45 :mod
# 46 who
# 47 pping
# 48 :ARG2
# 49 out
# 50 :op2
# 51 play
# 52 :ARG0
# 53 political
# 54 -
# 55 party
# 56 :ARG1
# 57 game
# 58 :mod
# 59 syntax
# 60 :ARG2
# 61 word
# 62 :example
# 63 and
# 64 :op1
# 65 disaster
# 66 :mod
# 67 ge
# 68 ology
# 69 :op2
# 70 disaster
# 71 :mod
# 72 earthquake
# 73 :time
# 74 thing
# 75 :ARG1-of
# 76 occasion
# 77 :mod
# 78 this
# 79 :ARG2
# 80 do
# 81 :ARG0
# 82 political
# 83 -
# 84 party
# 94 :name
# 95 name
# 96 :op1
# 97 C
# 98 CP
# 99 :ARG1
# 100 thing
# 101 :quant
# 102 lot
# 103 :mod
# 104 sort
# 105 :mod
# 106 this
# 107 :time
# 108 past
# ERROR
# think :ARG0 i :ARG1 possible :ARG1 judge :ARG0 we :ARG1 extent :extent-of and :op1 damage :op2 destroy :location zone :mod disaster :mod earthquake :manner broad :condition possible :ARG1 simulate :ARG0 government-organization :wiki China_Earthquake_Administration :name name :op1 Earthquake :op2 Administration :poss we :ARG1 earthquake :mod big :location belt :mod earthquake :mod mountain :wiki Longmen_Mountains :name name :op1 Longmenshan :mod this :time beforehand :time measure :ARG0 government-organization :ARG1 quake :ARG3 seismic-quantity :quant 7.8 :time day :mod that :ARG1-of mean :ARG2 date-entity :month 5 :day 12
# think :ARG0 i :ARG1 possible :ARG1 judge :ARG0 we :ARG1 extent :extent-of and :op1 damage :op2 destroy :location zone :mod disaster :mod earthquake :manner broad :condition possible :ARG1 simulate :ARG0 government-organization :wiki China_Earthquake_Administration :name name :op1 Earthquake :op2 Administration :poss we :ARG1 earthquake :mod big :location belt :mod earthquake :mod mountain :wiki Longmen_Mountains :name name :op1 Longmenshan :mod this :time beforehand :time measure :ARG0 government-organization :ARG1 quake :ARG3 seismic-quantity :quant 7.8 :time day :mod that :ARG1-of mean :ARG2 date-entity :month 5 :day 12
# 0 think
# 1 :ARG0
# 2
# 3 i
# 4 :ARG1
# 5 possible
# 6 :ARG1
# 7 judge
# 8 :ARG0
# 9 we
# 10 :ARG1
# 11 extent
# 12 :extent-of
# 13 and
# 14 :op1
# 15 damage
# 16 :op2
# 17 destroy
# 18 :location
# 19 zone
# 20 :mod
# 21 disaster
# 22 :mod
# 23 earthquake
# 24 :manner
# 25 broad
# 26 :condition
# 27 possible
# 28 :ARG1
# 29 simulate
# 30 :ARG0
# 31 government
# 32 -
# 33 organiz
# 34 ation
# 46 :name
# 47 name
# 48 :op1
# 49 Earth
# 50 qua
# 51 ke
# 52 :op2
# 53 Administration
# 54 :poss
# 55 we
# 56 :ARG1
# 57 earthquake
# 58 :mod
# 59 big
# 60 :location
# 61 belt
# 62 :mod
# 63 earthquake
# 64 :mod
# 65 mountain
# 75 :name
# 76 name
# 77 :op1
# 78 Long
# 79 men
# 80 s
# 81 han
# 82 :mod
# 83 this
# 84 :time
# 85 beforehand
# 86 :time
# 87 measure
# 88 :ARG0
# 89 government
# 90 -
# 91 organiz
# 92 ation
# 93 :ARG1
# 94
# 95 qua
# 96 ke
# 97 :ARG3
# 98 seismic
# 99 -
# 100 quant
# 101 ity
# 102 :quant
# 103 7.
# 104 8
# 105 :time
# 106 day
# 107 :mod
# 108 that
# 109 :ARG1-of
# 110 mean
# 111 :ARG2
# 112 date
# 113 -
# 114 ent
# 115 ity
# 116 :month
# 117 5
# 118 :day
# 119 12
# ERROR
# recommend :ARG1 conform :ARG1 circumstance :mod all :example and :op1 block :ARG1 road :ARG3 debris :op2 obstruct :ARG0 rain :manner heavy :ARG1 drop :manner parachute :op3 out :ARG1 power :op4 out :ARG1 communicate :ARG2 expect :condition design :ARG1 program :purpose simulate :manner good
# recommend :ARG1 conform :ARG1 circumstance :mod all :example and :op1 block :ARG1 road :ARG3 debris :op2 obstruct :ARG0 rain :manner heavy :ARG1 drop :manner parachute :op3 out :ARG1 power :op4 out :ARG1 communicate :ARG2 expect :condition design :ARG1 program :purpose simulate :manner good
# 0 recommend
# 1 :ARG1
# 2 conform
# 3 :ARG1
# 4 circumstance
# 5 :mod
# 6 all
# 7 :example
# 8 and
# 9 :op1
# 10 block
# 11 :ARG1
# 12 road
# 13 :ARG3
# 14 debris
# 15 :op2
# 16
# 17 o
# 18 b
# 19 struct
# 20 :ARG0
# 21 rain
# 22 :manner
# 23 heavy
# 24 :ARG1
# 25 drop
# 26 :manner
# 27 par
# 28 ach
# 29 ute
# 30 :op3
# 31 out
# 32 :ARG1
# 33 power
# 34 :op4
# 35 out
# 36 :ARG1
# 37 communicate
# 38 :ARG2
# 39 expect
# 40 :condition
# 41 design
# 42 :ARG1
# 43 program
# 44 :purpose
# 45 simulate
# 46 :manner
# 47 good
# ERROR
# multi-sentence :snt1 plan :ARG1 plan :ARG0 headquarters :poss military :wiki People's_Liberation_Army :name name :op1 Liberation :op2 Army :mod contingency :mod emergency :ARG1-of cause :ARG0 and :op1 rush :ARG0 soldier :mod all :ARG2 county :wiki Wenchuan_County :name name :op1 Wenchuan :ARG1-of straight :op2 send :polarity - :ARG1 troop :ARG5 and :op1 city :wiki Beichuan_Qiang_Autonomous_County :name name :op1 Beichuan :op2 city :wiki Qingchuan_County :name name :op1 Qingchuan :op3 city :wiki Longnan :name name :op1 Longnan :location province :wiki Gansu :name name :op1 Gansu :ARG1-of hit :ARG1-of bad :time immediate :time instance :mod this :ARG1-of obvious :mod contingency :ARG1-of design :polarity - :manner assume :ARG1 earthquake :ARG2 thing :ARG2-of condition :ARG1-of instead-of :snt2 consider :ARG1 extent :extent-of area :mod disaster :mod full :time after :quant temporal-quantity :quant 24 :unit hour :mod only
# multi-sentence :snt1 plan :ARG1 plan :ARG0 headquarters :poss military :wiki People's_Liberation_Army :name name :op1 Liberation :op2 Army :mod contingency :mod emergency :ARG1-of cause :ARG0 and :op1 rush :ARG0 soldier :mod all :ARG2 county :wiki Wenchuan_County :name name :op1 Wenchuan :ARG1-of straight :op2 send :polarity - :ARG1 troop :ARG5 and :op1 city :wiki Beichuan_Qiang_Autonomous_County :name name :op1 Beichuan :op2 city :wiki Qingchuan_County :name name :op1 Qingchuan :op3 city :wiki Longnan :name name :op1 Longnan :location province :wiki Gansu :name name :op1 Gansu :ARG1-of hit :ARG1-of bad :time immediate :time instance :mod this :ARG1-of obvious :mod contingency :ARG1-of design :polarity - :manner assume :ARG1 earthquake :ARG2 thing :ARG2-of condition :ARG1-of instead-of :snt2 consider :ARG1 extent :extent-of area :mod disaster :mod full :time after :quant temporal-quantity :quant 24 :unit hour :mod only
# 0 multi
# 1 -
# 2 sent
# 3 ence
# 4 :snt1
# 5 plan
# 6 :ARG1
# 7 plan
# 8 :ARG0
# 9 headquarters
# 10 :poss
# 11 military
# 23 :name
# 24 name
# 25 :op1
# 26 Liber
# 27 ation
# 28 :op2
# 29 Army
# 30 :mod
# 31 cont
# 32 ing
# 33 ency
# 34 :mod
# 35 emergency
# 36 :ARG1-of
# 37 cause
# 38 :ARG0
# 39 and
# 40 :op1
# 41 rush
# 42 :ARG0
# 43 soldier
# 44 :mod
# 45 all
# 46 :ARG2
# 47 county
# 56 :name
# 57 name
# 58 :op1
# 59 We
# 60 n
# 61 chu
# 62 an
# 63 :ARG1-of
# 64 straight
# 65 :op2
# 66 send
# 67 :polarity
# 68
# 69 -
# 70 :ARG1
# 71 troop
# 72 :ARG5
# 73 and
# 74 :op1
# 75 city
# 91 :name
# 92 name
# 93 :op1
# 94 Bei
# 95 chu
# 96 an
# 97 :op2
# 98 city
# 107 :name
# 108 name
# 109 :op1
# 110 Q
# 111 ing
# 112 chu
# 113 an
# 114 :op3
# 115 city
# 117 Long
# 118 n
# 119 an
# 120 :name
# 121 name
# 122 :op1
# 123 Long
# 124 n
# 125 an
# 126 :location
# 127 province
# 129 Gan
# 130 s
# 131 u
# 132 :name
# 133 name
# 134 :op1
# 135 Gan
# 136 s
# 137 u
# 138 :ARG1-of
# 139 hit
# 140 :ARG1-of
# 141 bad
# 142 :time
# 143 immediate
# 144 :time
# 145 instance
# 146 :mod
# 147 this
# 148 :ARG1-of
# 149 obvious
# 150 :mod
# 151 cont
# 152 ing
# 153 ency
# 154 :ARG1-of
# 155 design
# 156 :polarity
# 157
# 158 -
# 159 :manner
# 160 assume
# 161 :ARG1
# 162 earthquake
# 163 :ARG2
# 164 thing
# 165 :ARG2-of
# 166 condition
# 167 :ARG1-of
# 168 instead
# 169 -
# 170 of
# 171 :snt2
# 172 consider
# 173 :ARG1
# 174 extent
# 175 :extent-of
# 176 area
# 177 :mod
# 178 disaster
# 179 :mod
# 180 full
# 181 :time
# 182 after
# 183 :quant
# 184 temp
# 185 oral
# 186 -
# 187 quant
# 188 ity
# 189 :quant
# 190 24
# 191 :unit
# 192 hour
# 193 :mod
# 194 only
# ERROR
# multi-sentence :snt2 possible :ARG1 maintain :ARG0 regiment :part-of military :wiki People's_Liberation_Army :name name :op1 Red :op2 Army :ARG1 contact :ARG0 regiment :ARG1 headquarters :mod central :poss military :manner rely :ARG0 regiment :ARG1 radio :ARG1-of batter :quant just :op1 1 :time past :snt1 and :op2 bring :ARG0 break-down :ARG1 communicate :ARG1 problem :ARG1-of serious :ARG2 surface :mod also :snt3 have-concession :ARG1 have :polarity - :ARG0 person :ARG1 way :manner-of deal :ARG2 fail :ARG0 communicate :time thing :ARG1-of occasion :mod this
# multi-sentence :snt2 possible :ARG1 maintain :ARG0 regiment :part-of military :wiki People's_Liberation_Army :name name :op1 Red :op2 Army :ARG1 contact :ARG0 regiment :ARG1 headquarters :mod central :poss military :manner rely :ARG0 regiment :ARG1 radio :ARG1-of batter :quant just :op1 1 :time past :snt1 and :op2 bring :ARG0 break-down :ARG1 communicate :ARG1 problem :ARG1-of serious :ARG2 surface :mod also :snt3 have-concession :ARG1 have :polarity - :ARG0 person :ARG1 way :manner-of deal :ARG2 fail :ARG0 communicate :time thing :ARG1-of occasion :mod this
# 0 multi
# 1 -
# 2 sent
# 3 ence
# 4 :snt2
# 5 possible
# 6 :ARG1
# 7 maintain
# 8 :ARG0
# 9 regimen
# 10 t
# 11 :part-of
# 12 military
# 24 :name
# 25 name
# 26 :op1
# 27 Red
# 28 :op2
# 29 Army
# 30 :ARG1
# 31 contact
# 32 :ARG0
# 33 regimen
# 34 t
# 35 :ARG1
# 36 headquarters
# 37 :mod
# 38 central
# 39 :poss
# 40 military
# 41 :manner
# 42
# 43 rely
# 44 :ARG0
# 45 regimen
# 46 t
# 47 :ARG1
# 48 radio
# 49 :ARG1-of
# 50 batter
# 51 :quant
# 52 just
# 53 :op1
# 54 1
# 55 :time
# 56 past
# 57 :snt1
# 58 and
# 59 :op2
# 60 bring
# 61 :ARG0
# 62 break
# 63 -
# 64 down
# 65 :ARG1
# 66 communicate
# 67 :ARG1
# 68 problem
# 69 :ARG1-of
# 70 serious
# 71 :ARG2
# 72 surface
# 73 :mod
# 74 also
# 75 :snt3
# 76 have
# 77 -
# 78 con
# 79 cession
# 80 :ARG1
# 81 have
# 82 :polarity
# 83
# 84 -
# 85 :ARG0
# 86 person
# 87 :ARG1
# 88 way
# 89 :manner-of
# 90 deal
# 91 :ARG2
# 92 fail
# 93 :ARG0
# 94 communicate
# 95 :time
# 96 thing
# 97 :ARG1-of
# 98 occasion
# 99 :mod
# 100 this
# ERROR
# clear :ARG1 construct :polarity - :ARG1 thing :ARG1-of prepare :time prior :op1 event :ARG1-of base :ARG2 simulate :ARG1 disaster :mod earthquake
# clear :ARG1 construct :polarity - :ARG1 thing :ARG1-of prepare :time prior :op1 event :ARG1-of base :ARG2 simulate :ARG1 disaster :mod earthquake
# 0 clear
# 1 :ARG1
# 2 construct
# 3 :polarity
# 4
# 5 -
# 6 :ARG1
# 7 thing
# 8 :ARG1-of
# 9 prepare
# 10 :time
# 11 prior
# 12 :op1
# 13 event
# 14 :ARG1-of
# 15 base
# 16 :ARG2
# 17 simulate
# 18 :ARG1
# 19 disaster
# 20 :mod
# 21 earthquake
# ERROR
# result :ARG1 or :op1 lack :ARG0 between :op1 thing :quant 2 :ARG1 layer :mod intermediate :part-of and :op1 organization :op2 unit :part-of party :op2 short :ARG1 between :ARG2 layer :ARG1-of serious :ARG2 possible :polarity - :ARG1 consider :ARG0 party :ARG1 issue :ARG1-of major :condition have :ARG1 issue :ARG1-of minor :quant endless :location at-hand :ARG0-of cause :ARG1 last :polarity - :ARG1 capable-01 :ARG2 long :ARG1 capable-01 :concession even-if :op1 capable :ARG1 party :degree high :ARG1-of cause :ARG0 drag :ARG0 thing :quant numerous :mod petty :ARG1 capable-01 :ARG2 down
# result :ARG1 or :op1 lack :ARG0 between :op1 thing :quant 2 :ARG1 layer :mod intermediate :part-of and :op1 organization :op2 unit :part-of party :op2 short :ARG1 between :ARG2 layer :ARG1-of serious :ARG2 possible :polarity - :ARG1 consider :ARG0 party :ARG1 issue :ARG1-of major :condition have :ARG1 issue :ARG1-of minor :quant endless :location at-hand :ARG0-of cause :ARG1 last :polarity - :ARG1 capable-01 :ARG2 long :ARG1 capable-01 :concession even-if :op1 capable :ARG1 party :degree high :ARG1-of cause :ARG0 drag :ARG0 thing :quant numerous :mod petty :ARG1 capable-01 :ARG2 down
# 0 result
# 1 :ARG1
# 2 or
# 3 :op1
# 4 lack
# 5 :ARG0
# 6 between
# 7 :op1
# 8 thing
# 9 :quant
# 10 2
# 11 :ARG1
# 12 layer
# 13 :mod
# 14 intermediate
# 15 :part-of
# 16 and
# 17 :op1
# 18 organization
# 19 :op2
# 20 unit
# 21 :part-of
# 22 party
# 23 :op2
# 24 short
# 25 :ARG1
# 26 between
# 27 :ARG2
# 28 layer
# 29 :ARG1-of
# 30 serious
# 31 :ARG2
# 32 possible
# 33 :polarity
# 34
# 35 -
# 36 :ARG1
# 37 consider
# 38 :ARG0
# 39 party
# 40 :ARG1
# 41 issue
# 42 :ARG1-of
# 43 major
# 44 :condition
# 45 have
# 46 :ARG1
# 47 issue
# 48 :ARG1-of
# 49 minor
# 50 :quant
# 51 endless
# 52 :location
# 53 at
# 54 -
# 55 hand
# 56 :ARG0-of
# 57 cause
# 58 :ARG1
# 59 last
# 60 :polarity
# 61
# 62 -
# 63 :ARG1
# 64 capable
# 65 -01
# 66 :ARG2
# 67 long
# 68 :ARG1
# 69 capable
# 70 -01
# 71 :concession
# 72 even
# 73 -
# 74 if
# 75 :op1
# 76 capable
# 77 :ARG1
# 78 party
# 79 :degree
# 80 high
# 81 :ARG1-of
# 82 cause
# 83 :ARG0
# 84 drag
# 85 :ARG0
# 86 thing
# 87 :quant
# 88 numerous
# 89 :mod
# 90
# 91 p
# 92 etty
# 93 :ARG1
# 94 capable
# 95 -01
# 96 :ARG2
# 97 down
# ERROR
# multi-sentence :snt1 possible :polarity - :ARG1 imagine :ARG1 this :time earthquake :wiki 1976_Tangshan_earthquake :name name :op1 Great :op2 Tangshan :op3 Earthquake :snt2 perform :ARG0 and :op1 branch :ARG1-of have-degree :ARG2 primary :ARG3 most :ARG5 branch :part-of party :op2 enterprise :op3 institution :ARG1-of public :ARG1 thing :example deal :ARG2 person :ARG1-of average :ARG1-of direct :mod petty :mod such :time or :op1 person :polarity - :ARG0-of volunteer :op2 person :polarity - :ARG0-of work :mod mental
# multi-sentence :snt1 possible :polarity - :ARG1 imagine :ARG1 this :time earthquake :wiki 1976_Tangshan_earthquake :name name :op1 Great :op2 Tangshan :op3 Earthquake :snt2 perform :ARG0 and :op1 branch :ARG1-of have-degree :ARG2 primary :ARG3 most :ARG5 branch :part-of party :op2 enterprise :op3 institution :ARG1-of public :ARG1 thing :example deal :ARG2 person :ARG1-of average :ARG1-of direct :mod petty :mod such :time or :op1 person :polarity - :ARG0-of volunteer :op2 person :polarity - :ARG0-of work :mod mental
# 0 multi
# 1 -
# 2 sent
# 3 ence
# 4 :snt1
# 5 possible
# 6 :polarity
# 7
# 8 -
# 9 :ARG1
# 10 imagine
# 11 :ARG1
# 12 this
# 13 :time
# 14 earthquake
# 27 :name
# 28 name
# 29 :op1
# 30 Great
# 31 :op2
# 32 Tang
# 33 s
# 34 han
# 35 :op3
# 36 Earth
# 37 qua
# 38 ke
# 39 :snt2
# 40 perform
# 41 :ARG0
# 42 and
# 43 :op1
# 44 branch
# 45 :ARG1-of
# 46 have
# 47 -
# 48 degree
# 49 :ARG2
# 50 primary
# 51 :ARG3
# 52 most
# 53 :ARG5
# 54 branch
# 55 :part-of
# 56 party
# 57 :op2
# 58 enterprise
# 59 :op3
# 60 institution
# 61 :ARG1-of
# 62 public
# 63 :ARG1
# 64 thing
# 65 :example
# 66 deal
# 67 :ARG2
# 68 person
# 69 :ARG1-of
# 70 average
# 71 :ARG1-of
# 72 direct
# 73 :mod
# 74
# 75 p
# 76 etty
# 77 :mod
# 78 such
# 79 :time
# 80 or
# 81 :op1
# 82 person
# 83 :polarity
# 84
# 85 -
# 86 :ARG0-of
# 87 volunteer
# 88 :op2
# 89 person
# 90 :polarity
# 91
# 92 -
# 93 :ARG0-of
# 94 work
# 95 :mod
# 96 mental
# ERROR
# and :op1 contact :ARG0 organization :mod grass-roots :ARG1 person :ARG0-of have-org-role :ARG1 organization :op2 contact :ARG0 person :ARG1-of average :ARG1 or :op1 system :poss person :op2 department :poss person :mod also :time as-soon-as :op1 earthquake :manner interdependent
# and :op1 contact :ARG0 organization :mod grass-roots :ARG1 person :ARG0-of have-org-role :ARG1 organization :op2 contact :ARG0 person :ARG1-of average :ARG1 or :op1 system :poss person :op2 department :poss person :mod also :time as-soon-as :op1 earthquake :manner interdependent
# 0 and
# 1 :op1
# 2 contact
# 3 :ARG0
# 4 organization
# 5 :mod
# 6 grass
# 7 -
# 8 root
# 9 s
# 10 :ARG1
# 11 person
# 12 :ARG0-of
# 13 have
# 14 -
# 15 org
# 16 -
# 17 rol
# 18 e
# 19 :ARG1
# 20 organization
# 21 :op2
# 22 contact
# 23 :ARG0
# 24 person
# 25 :ARG1-of
# 26 average
# 27 :ARG1
# 28 or
# 29 :op1
# 30 system
# 31 :poss
# 32 person
# 33 :op2
# 34 department
# 35 :poss
# 36 person
# 37 :mod
# 38 also
# 39 :time
# 40 as
# 41 -
# 42 s
# 43 o
# 44 on
# 45 -
# 46 a
# 47 s
# 48 :op1
# 49 earthquake
# 50 :manner
# 51 inter
# 52 dependent
# ERROR
# forget :ARG1 earthquake :wiki 1976_Tangshan_earthquake :name name :op1 Great :op2 Tangshan :op3 Earthquake :time before :op1 now :quant few :op1 temporal-quantity :quant 1 :unit year :mod just :ARG1-of cause :ARG0 act :ARG0 everyone :purpose make :ARG0 everyone :ARG1 and :op1 outstanding :domain effort :ARG1 rescue :degree very :op2 succeed :ARG0 effort-01 :degree very :manner lead :ARG0 organization :mod level :ARG1-of have-degree :ARG2 high :ARG3 more :ARG1-of centralize :time and :op1 reform :op2 open-up :mod subsequent :degree altogether
# forget :ARG1 earthquake :wiki 1976_Tangshan_earthquake :name name :op1 Great :op2 Tangshan :op3 Earthquake :time before :op1 now :quant few :op1 temporal-quantity :quant 1 :unit year :mod just :ARG1-of cause :ARG0 act :ARG0 everyone :purpose make :ARG0 everyone :ARG1 and :op1 outstanding :domain effort :ARG1 rescue :degree very :op2 succeed :ARG0 effort-01 :degree very :manner lead :ARG0 organization :mod level :ARG1-of have-degree :ARG2 high :ARG3 more :ARG1-of centralize :time and :op1 reform :op2 open-up :mod subsequent :degree altogether
# 0 forget
# 1 :ARG1
# 2 earthquake
# 15 :name
# 16 name
# 17 :op1
# 18 Great
# 19 :op2
# 20 Tang
# 21 s
# 22 han
# 23 :op3
# 24 Earth
# 25 qua
# 26 ke
# 27 :time
# 28 before
# 29 :op1
# 30 now
# 31 :quant
# 32 few
# 33 :op1
# 34 temp
# 35 oral
# 36 -
# 37 quant
# 38 ity
# 39 :quant
# 40 1
# 41 :unit
# 42 year
# 43 :mod
# 44 just
# 45 :ARG1-of
# 46 cause
# 47 :ARG0
# 48 act
# 49 :ARG0
# 50 everyone
# 51 :purpose
# 52 make
# 53 :ARG0
# 54 everyone
# 55 :ARG1
# 56 and
# 57 :op1
# 58 outstanding
# 59 :domain
# 60 effort
# 61 :ARG1
# 62 rescue
# 63 :degree
# 64 very
# 65 :op2
# 66 succeed
# 67 :ARG0
# 68 effort
# 69 -01
# 70 :degree
# 71 very
# 72 :manner
# 73 lead
# 74 :ARG0
# 75 organization
# 76 :mod
# 77 level
# 78 :ARG1-of
# 79 have
# 80 -
# 81 degree
# 82 :ARG2
# 83 high
# 84 :ARG3
# 85 more
# 86 :ARG1-of
# 87 central
# 88 ize
# 89 :time
# 90 and
# 91 :op1
# 92 reform
# 93 :op2
# 94 open
# 95 -
# 96 up
# 97 :mod
# 98 subsequent
# 99 :degree
# 100 altogether
# ERROR
# obvious :ARG1 and :op1 leave :polarity - :ARG1 or :op1 problem :topic society :op2 problem :topic politics :op2 leave :polarity - :ARG1 sequela :ARG0-of cause :ARG1 headache :beneficiary generation :time after :op1 then :time then
# obvious :ARG1 and :op1 leave :polarity - :ARG1 or :op1 problem :topic society :op2 problem :topic politics :op2 leave :polarity - :ARG1 sequela :ARG0-of cause :ARG1 headache :beneficiary generation :time after :op1 then :time then
# 0 obvious
# 1 :ARG1
# 2 and
# 3 :op1
# 4 leave
# 5 :polarity
# 6
# 7 -
# 8 :ARG1
# 9 or
# 10 :op1
# 11 problem
# 12 :topic
# 13 society
# 14 :op2
# 15 problem
# 16 :topic
# 17 politics
# 18 :op2
# 19 leave
# 20 :polarity
# 21
# 22 -
# 23 :ARG1
# 24 sequel
# 25 a
# 26 :ARG0-of
# 27 cause
# 28 :ARG1
# 29 headache
# 30 :beneficiary
# 31 generation
# 32 :time
# 33 after
# 34 :op1
# 35 then
# 36 :time
# 37 then
# ERROR
# contrast :ARG2 and :op1 lack :ARG0 it :ARG1 benefit :degree total :polarity - :op2 believe :ARG0 it :ARG1 benefit :ARG0 it :manner and :op1 serve :ARG0 it :ARG1 strip :ARG0 it :ARG1 benevolence :mod false :ARG2-of compose :ARG1 skin :part-of and :op1 elitist :op2 politician :op3 capitalist :mod outer :op2 expose :ARG0 it :ARG1 core :ARG1-of rot :mod cannibal :location inside :op1 and :mod once-and-for-all :ARG1-of have-degree :ARG2 great :ARG3 most
# contrast :ARG2 and :op1 lack :ARG0 it :ARG1 benefit :degree total :polarity - :op2 believe :ARG0 it :ARG1 benefit :ARG0 it :manner and :op1 serve :ARG0 it :ARG1 strip :ARG0 it :ARG1 benevolence :mod false :ARG2-of compose :ARG1 skin :part-of and :op1 elitist :op2 politician :op3 capitalist :mod outer :op2 expose :ARG0 it :ARG1 core :ARG1-of rot :mod cannibal :location inside :op1 and :mod once-and-for-all :ARG1-of have-degree :ARG2 great :ARG3 most
# 0 contrast
# 1 :ARG2
# 2 and
# 3 :op1
# 4 lack
# 5 :ARG0
# 6 it
# 7 :ARG1
# 8 benefit
# 9 :degree
# 10 total
# 11 :polarity
# 12
# 13 -
# 14 :op2
# 15 believe
# 16 :ARG0
# 17 it
# 18 :ARG1
# 19 benefit
# 20 :ARG0
# 21 it
# 22 :manner
# 23 and
# 24 :op1
# 25 serve
# 26 :ARG0
# 27 it
# 28 :ARG1
# 29 strip
# 30 :ARG0
# 31 it
# 32 :ARG1
# 33
# 34 bene
# 35 vol
# 36 ence
# 37 :mod
# 38 false
# 39 :ARG2-of
# 40 compose
# 41 :ARG1
# 42 skin
# 43 :part-of
# 44 and
# 45 :op1
# 46
# 47 e
# 48 litis
# 49 t
# 50 :op2
# 51 politician
# 52 :op3
# 53 capital
# 54 ist
# 55 :mod
# 56 outer
# 57 :op2
# 58 expose
# 59 :ARG0
# 60 it
# 61 :ARG1
# 62 core
# 63 :ARG1-of
# 64
# 65 rot
# 66 :mod
# 67 can
# 68 n
# 69 i
# 70 bal
# 71 :location
# 72 inside
# 73 :op1
# 74 and
# 75 :mod
# 76 once
# 77 -
# 78 and
# 79 -
# 80 for
# 81 -
# 82 all
# 83 :ARG1-of
# 84 have
# 85 -
# 86 degree
# 87 :ARG2
# 88 great
# 89 :ARG3
# 90 most
# ERROR
# and :op2 benefit :ARG0 come :ARG1 person :ARG1-of delude :quant many :ARG2 sense :ARG0 person :mod additional
# and :op2 benefit :ARG0 come :ARG1 person :ARG1-of delude :quant many :ARG2 sense :ARG0 person :mod additional
# 0 and
# 1 :op2
# 2 benefit
# 3 :ARG0
# 4 come
# 5 :ARG1
# 6 person
# 7 :ARG1-of
# 8 de
# 9 lude
# 10 :quant
# 11 many
# 12 :ARG2
# 13 sense
# 14 :ARG0
# 15 person
# 16 :mod
# 17 additional
# ERROR
# and :op1 lay :ARG1 thing :mod abstract :mod this :ARG2 aside :duration temporary :op2 avoid :ARG1 speak :ARG1-of long :op3 say :ARG1 detail :ARG0-of embarrass :ARG1 and :op1 elitist :op2 politician :op3 capitalist :degree high :quant few :mod only
# and :op1 lay :ARG1 thing :mod abstract :mod this :ARG2 aside :duration temporary :op2 avoid :ARG1 speak :ARG1-of long :op3 say :ARG1 detail :ARG0-of embarrass :ARG1 and :op1 elitist :op2 politician :op3 capitalist :degree high :quant few :mod only
# 0 and
# 1 :op1
# 2 lay
# 3 :ARG1
# 4 thing
# 5 :mod
# 6 abstract
# 7 :mod
# 8 this
# 9 :ARG2
# 10 aside
# 11 :duration
# 12 temporary
# 13 :op2
# 14 avoid
# 15 :ARG1
# 16 speak
# 17 :ARG1-of
# 18 long
# 19 :op3
# 20 say
# 21 :ARG1
# 22 detail
# 23 :ARG0-of
# 24 emb
# 25 arra
# 26 s
# 27 s
# 28 :ARG1
# 29 and
# 30 :op1
# 31
# 32 e
# 33 litis
# 34 t
# 35 :op2
# 36 politician
# 37 :op3
# 38 capital
# 39 ist
# 40 :degree
# 41 high
# 42 :quant
# 43 few
# 44 :mod
# 45 only
# ERROR
# finish :ARG0 person :ARG1-of expert :ARG1 say :ARG0 person :ARG1 idea :domain sacrifice :ARG0 you :ARG1 you :ARG2 help :ARG0 you :ARG1 other :mod foolish :time have :ARG0 person :ARG0-of lead :ARG1 thing :polarity - :ARG1-of choose :ARG2-of except :ARG1 call :ARG0 person :ARG1 devote :manner selfless :mod again :mod once :time just
# finish :ARG0 person :ARG1-of expert :ARG1 say :ARG0 person :ARG1 idea :domain sacrifice :ARG0 you :ARG1 you :ARG2 help :ARG0 you :ARG1 other :mod foolish :time have :ARG0 person :ARG0-of lead :ARG1 thing :polarity - :ARG1-of choose :ARG2-of except :ARG1 call :ARG0 person :ARG1 devote :manner selfless :mod again :mod once :time just
# 0 finish
# 1 :ARG0
# 2 person
# 3 :ARG1-of
# 4 expert
# 5 :ARG1
# 6 say
# 7 :ARG0
# 8 person
# 9 :ARG1
# 10 idea
# 11 :domain
# 12 sacrifice
# 13 :ARG0
# 14 you
# 15 :ARG1
# 16 you
# 17 :ARG2
# 18 help
# 19 :ARG0
# 20 you
# 21 :ARG1
# 22 other
# 23 :mod
# 24 foolish
# 25 :time
# 26 have
# 27 :ARG0
# 28 person
# 29 :ARG0-of
# 30 lead
# 31 :ARG1
# 32 thing
# 33 :polarity
# 34
# 35 -
# 36 :ARG1-of
# 37 choose
# 38 :ARG2-of
# 39 except
# 40 :ARG1
# 41 call
# 42 :ARG0
# 43 person
# 44 :ARG1
# 45 devote
# 46 :manner
# 47 self
# 48 less
# 49 :mod
# 50 again
# 51 :mod
# 52 once
# 53 :time
# 54 just
# ERROR
# chicanery :domain this :mod mere :ARG2-of have-degree :ARG1 this :ARG3 to-the-point :ARG6 obligate :ARG2 come-to-mind :ARG1 person :ARG2 idea :time before :op1 engage :ARG0 person :ARG2 behave :ARG0 person :mod sort :mod this :example and :op1 save :ARG0 person :ARG1 life :op2 donate :ARG0 person :ARG2 charity :manner flash :ARG1 idea
# chicanery :domain this :mod mere :ARG2-of have-degree :ARG1 this :ARG3 to-the-point :ARG6 obligate :ARG2 come-to-mind :ARG1 person :ARG2 idea :time before :op1 engage :ARG0 person :ARG2 behave :ARG0 person :mod sort :mod this :example and :op1 save :ARG0 person :ARG1 life :op2 donate :ARG0 person :ARG2 charity :manner flash :ARG1 idea
# 0 chic
# 1 an
# 2 ery
# 3 :domain
# 4 this
# 5 :mod
# 6 mere
# 7 :ARG2-of
# 8 have
# 9 -
# 10 degree
# 11 :ARG1
# 12 this
# 13 :ARG3
# 14 to
# 15 -
# 16 the
# 17 -
# 18 point
# 19 :ARG6
# 20
# 21 obligate
# 22 :ARG2
# 23 come
# 24 -
# 25 to
# 26 -
# 27 mind
# 28 :ARG1
# 29 person
# 30 :ARG2
# 31 idea
# 32 :time
# 33 before
# 34 :op1
# 35 engage
# 36 :ARG0
# 37 person
# 38 :ARG2
# 39 behave
# 40 :ARG0
# 41 person
# 42 :mod
# 43 sort
# 44 :mod
# 45 this
# 46 :example
# 47 and
# 48 :op1
# 49 save
# 50 :ARG0
# 51 person
# 52 :ARG1
# 53 life
# 54 :op2
# 55 donate
# 56 :ARG0
# 57 person
# 58 :ARG2
# 59 charity
# 60 :manner
# 61 flash
# 62 :ARG1
# 63 idea
# ERROR
# foolish :polarity amr-unknown :domain i :condition do :ARG0 i :ARG1 this
# foolish :polarity amr-unknown :domain i :condition do :ARG0 i :ARG1 this
# 0 foolish
# 1 :polarity
# 2 am
# 3 r
# 4 -
# 5 un
# 6 known
# 7 :domain
# 8
# 9 i
# 10 :condition
# 11 do
# 12 :ARG0
# 13
# 14 i
# 15 :ARG1
# 16 this
# ERROR
# and :op2 probable :domain idea :ARG2-of come-to-mind :ARG1 person :time see :ARG0 person :ARG1 work :ARG0 firm :mod that :ARG1-of private :ARG0-of manufacture :ARG1 tent :location and :op1 province :wiki Jiangsu :name name :op1 Jiangsu :op2 province :wiki Zhejiang :name name :op1 Zhejiang :ARG1 produce :ARG0 firm :ARG1 tent :quant more :mod overtime :medium publication :wiki China_Central_Television :name name :op1 CCTV :ARG1-of fear :ARG0 idea :ord ordinal-entity :value 1 :domain strike :ARG0 capitalist :mod this :manner big :time time :mod this
# and :op2 probable :domain idea :ARG2-of come-to-mind :ARG1 person :time see :ARG0 person :ARG1 work :ARG0 firm :mod that :ARG1-of private :ARG0-of manufacture :ARG1 tent :location and :op1 province :wiki Jiangsu :name name :op1 Jiangsu :op2 province :wiki Zhejiang :name name :op1 Zhejiang :ARG1 produce :ARG0 firm :ARG1 tent :quant more :mod overtime :medium publication :wiki China_Central_Television :name name :op1 CCTV :ARG1-of fear :ARG0 idea :ord ordinal-entity :value 1 :domain strike :ARG0 capitalist :mod this :manner big :time time :mod this
# 0 and
# 1 :op2
# 2 probable
# 3 :domain
# 4 idea
# 5 :ARG2-of
# 6 come
# 7 -
# 8 to
# 9 -
# 10 mind
# 11 :ARG1
# 12 person
# 13 :time
# 14 see
# 15 :ARG0
# 16 person
# 17 :ARG1
# 18 work
# 19 :ARG0
# 20 firm
# 21 :mod
# 22 that
# 23 :ARG1-of
# 24 private
# 25 :ARG0-of
# 26 manufacture
# 27 :ARG1
# 28 tent
# 29 :location
# 30 and
# 31 :op1
# 32 province
# 34 Ji
# 35 ang
# 36 s
# 37 u
# 38 :name
# 39 name
# 40 :op1
# 41 Ji
# 42 ang
# 43 s
# 44 u
# 45 :op2
# 46 province
# 48 Z
# 49 he
# 50 j
# 51 i
# 52 ang
# 53 :name
# 54 name
# 55 :op1
# 56 Z
# 57 he
# 58 j
# 59 i
# 60 ang
# 61 :ARG1
# 62 produce
# 63 :ARG0
# 64 firm
# 65 :ARG1
# 66 tent
# 67 :quant
# 68 more
# 69 :mod
# 70 overtime
# 71 :medium
# 72 publication
# 81 :name
# 82 name
# 83 :op1
# 84 CCTV
# 85 :ARG1-of
# 86 fear
# 87 :ARG0
# 88 idea
# 89 :ord
# 90 ordin
# 91 al
# 92 -
# 93 ent
# 94 ity
# 95 :value
# 96 1
# 97 :domain
# 98 strike
# 99 :ARG0
# 100 capital
# 101 ist
# 102 :mod
# 103 this
# 104 :manner
# 105 big
# 106 :time
# 107 time
# 108 :mod
# 109 this
# ERROR
# and :op1 get :ARG0 capitalist :mod this :ARG1 form :purpose order :mod big :ARG1-of instead-of :ARG2 get :ARG0 capitalist :mod that :ARG1 form :ARG1-of cause :ARG0 amr-unknown :op2 sure :ARG1 possible :polarity - :ARG1 involve :ARG1 anything :mod fishy :polarity amr-unknown
# and :op1 get :ARG0 capitalist :mod this :ARG1 form :purpose order :mod big :ARG1-of instead-of :ARG2 get :ARG0 capitalist :mod that :ARG1 form :ARG1-of cause :ARG0 amr-unknown :op2 sure :ARG1 possible :polarity - :ARG1 involve :ARG1 anything :mod fishy :polarity amr-unknown
# 0 and
# 1 :op1
# 2 get
# 3 :ARG0
# 4 capital
# 5 ist
# 6 :mod
# 7 this
# 8 :ARG1
# 9 form
# 10 :purpose
# 11 order
# 12 :mod
# 13 big
# 14 :ARG1-of
# 15 instead
# 16 -
# 17 of
# 18 :ARG2
# 19 get
# 20 :ARG0
# 21 capital
# 22 ist
# 23 :mod
# 24 that
# 25 :ARG1
# 26 form
# 27 :ARG1-of
# 28 cause
# 29 :ARG0
# 30 am
# 31 r
# 32 -
# 33 un
# 34 known
# 35 :op2
# 36 sure
# 37 :ARG1
# 38 possible
# 39 :polarity
# 40
# 41 -
# 42 :ARG1
# 43 involve
# 44 :ARG1
# 45 anything
# 46 :mod
# 47 fish
# 48 y
# 49 :polarity
# 50 am
# 51 r
# 52 -
# 53 un
# 54 known
# ERROR
# talk :ARG1 file :ARG1 complain :ARG3 company :wiki - :name name :op1 Xinghui :op2 Travel :op3 Agency :time process :mod this :mod again
# talk :ARG1 file :ARG1 complain :ARG3 company :wiki - :name name :op1 Xinghui :op2 Travel :op3 Agency :time process :mod this :mod again
# 0 talk
# 1 :ARG1
# 2 file
# 3 :ARG1
# 4 complain
# 5 :ARG3
# 6 company
# 10 :name
# 11 name
# 12 :op1
# 13
# 14 X
# 15 ing
# 16 hui
# 17 :op2
# 18 Travel
# 19 :op3
# 20 Agency
# 21 :time
# 22 process
# 23 :mod
# 24 this
# 25 :mod
# 26 again
# ERROR
# cause :ARG0 recommend :ARG1 fulfill :ARG0 they :ARG1 thing :ARG2-of obligate :ARG0 contract :ARG1-of sign :ARG0 they :ARG1 they :ARG1-of mean :ARG2 drive :ARG0 they :beneficiary person :destination city :wiki Sydney :name name :op1 Sydney :source city :wiki Canberra :name name :op1 Canberra :direction back :mod still :concession even-if :op1 owe :ARG0 we :ARG1 fee :poss they :mod hour :ARG2 they :ARG1 file :ARG0 we :ARG1 complain
# cause :ARG0 recommend :ARG1 fulfill :ARG0 they :ARG1 thing :ARG2-of obligate :ARG0 contract :ARG1-of sign :ARG0 they :ARG1 they :ARG1-of mean :ARG2 drive :ARG0 they :beneficiary person :destination city :wiki Sydney :name name :op1 Sydney :source city :wiki Canberra :name name :op1 Canberra :direction back :mod still :concession even-if :op1 owe :ARG0 we :ARG1 fee :poss they :mod hour :ARG2 they :ARG1 file :ARG0 we :ARG1 complain
# 0 cause
# 1 :ARG0
# 2 recommend
# 3 :ARG1
# 4 fulfill
# 5 :ARG0
# 6 they
# 7 :ARG1
# 8 thing
# 9 :ARG2-of
# 10
# 11 obligate
# 12 :ARG0
# 13 contract
# 14 :ARG1-of
# 15 sign
# 16 :ARG0
# 17 they
# 18 :ARG1
# 19 they
# 20 :ARG1-of
# 21 mean
# 22 :ARG2
# 23 drive
# 24 :ARG0
# 25 they
# 26 :beneficiary
# 27 person
# 28 :destination
# 29 city
# 31 Sydney
# 32 :name
# 33 name
# 34 :op1
# 35 Sydney
# 36 :source
# 37 city
# 39 Canberra
# 40 :name
# 41 name
# 42 :op1
# 43 Canberra
# 44 :direction
# 45 back
# 46 :mod
# 47 still
# 48 :concession
# 49 even
# 50 -
# 51 if
# 52 :op1
# 53
# 54 ow
# 55 e
# 56 :ARG0
# 57 we
# 58 :ARG1
# 59 fee
# 60 :poss
# 61 they
# 62 :mod
# 63 hour
# 64 :ARG2
# 65 they
# 66 :ARG1
# 67 file
# 68 :ARG0
# 69 we
# 70 :ARG1
# 71 complain
# ERROR
# sure :ARG1 have :polarity - :ARG0 company :wiki - :name name :op1 Xinghui :ARG1 way :instrument-of win :ARG0 company :ARG2 sue :condition go :ARG1 sue-02 :ARG4 court :condition as-long-as :op1 stick :ARG1 we :ARG2 issue :mod this
# sure :ARG1 have :polarity - :ARG0 company :wiki - :name name :op1 Xinghui :ARG1 way :instrument-of win :ARG0 company :ARG2 sue :condition go :ARG1 sue-02 :ARG4 court :condition as-long-as :op1 stick :ARG1 we :ARG2 issue :mod this
# 0 sure
# 1 :ARG1
# 2 have
# 3 :polarity
# 4
# 5 -
# 6 :ARG0
# 7 company
# 9
# 10 -
# 11 :name
# 12 name
# 13 :op1
# 14
# 15 X
# 16 ing
# 17 hui
# 18 :ARG1
# 19 way
# 20 :instrument-of
# 21 win
# 22 :ARG0
# 23 company
# 24 :ARG2
# 25 su
# 26 e
# 27 :condition
# 28 go
# 29 :ARG1
# 30 su
# 31 e
# 32 -
# 33 02
# 34 :ARG4
# 35 court
# 36 :condition
# 37 as
# 38 -
# 39 long
# 40 -
# 41 a
# 42 s
# 43 :op1
# 44 stick
# 45 :ARG1
# 46 we
# 47 :ARG2
# 48 issue
# 49 :mod
# 50 this
# ERROR
# multi-sentence :snt1 contrast :ARG2 surprise :ARG0 attitude :poss union :consist-of person :ARG0-of study :topic appeal :mod this :ARG1 i :degree great :snt2 seem :ARG1 reluctant :ARG0 they :ARG1 publicize :ARG0 they :ARG1 contract :degree very
# multi-sentence :snt1 contrast :ARG2 surprise :ARG0 attitude :poss union :consist-of person :ARG0-of study :topic appeal :mod this :ARG1 i :degree great :snt2 seem :ARG1 reluctant :ARG0 they :ARG1 publicize :ARG0 they :ARG1 contract :degree very
# 0 multi
# 1 -
# 2 sent
# 3 ence
# 4 :snt1
# 5 contrast
# 6 :ARG2
# 7 surprise
# 8 :ARG0
# 9 attitude
# 10 :poss
# 11 union
# 12 :consist-of
# 13 person
# 14 :ARG0-of
# 15 study
# 16 :topic
# 17 appeal
# 18 :mod
# 19 this
# 20 :ARG1
# 21
# 22 i
# 23 :degree
# 24 great
# 25 :snt2
# 26 seem
# 27 :ARG1
# 28 reluctant
# 29 :ARG0
# 30 they
# 31 :ARG1
# 32 public
# 33 ize
# 34 :ARG0
# 35 they
# 36 :ARG1
# 37 contract
# 38 :degree
# 39 very
# ERROR
# and :op1 lie :ARG0 they :mod even :op2 say :ARG0 they :ARG1 feel :ARG0 and :op1 they :op2 company :wiki - :name name :op1 Xinghui :ARG1 make :ARG0 sign :ARG0 they :ARG1 contract :ARG2 company :ARG1 feel :ARG0 and :ARG1 resemble :ARG1 and :ARG2 stranger :mod rather :time initial :ARG1-of cause :ARG0 do :ARG0 and :ARG1 it :ARG2 motherland
# and :op1 lie :ARG0 they :mod even :op2 say :ARG0 they :ARG1 feel :ARG0 and :op1 they :op2 company :wiki - :name name :op1 Xinghui :ARG1 make :ARG0 sign :ARG0 they :ARG1 contract :ARG2 company :ARG1 feel :ARG0 and :ARG1 resemble :ARG1 and :ARG2 stranger :mod rather :time initial :ARG1-of cause :ARG0 do :ARG0 and :ARG1 it :ARG2 motherland
# 0 and
# 1 :op1
# 2 lie
# 3 :ARG0
# 4 they
# 5 :mod
# 6 even
# 7 :op2
# 8 say
# 9 :ARG0
# 10 they
# 11 :ARG1
# 12 feel
# 13 :ARG0
# 14 and
# 15 :op1
# 16 they
# 17 :op2
# 18 company
# 22 :name
# 23 name
# 24 :op1
# 25
# 26 X
# 27 ing
# 28 hui
# 29 :ARG1
# 30 make
# 31 :ARG0
# 32 sign
# 33 :ARG0
# 34 they
# 35 :ARG1
# 36 contract
# 37 :ARG2
# 38 company
# 39 :ARG1
# 40 feel
# 41 :ARG0
# 42 and
# 43 :ARG1
# 44
# 45 resemble
# 46 :ARG1
# 47 and
# 48 :ARG2
# 49 stranger
# 50 :mod
# 51 rather
# 52 :time
# 53 initial
# 54 :ARG1-of
# 55 cause
# 56 :ARG0
# 57 do
# 58 :ARG0
# 59 and
# 60 :ARG1
# 61 it
# 62 :ARG2
# 63 mother
# 64 l
# 65 and
# ERROR
# sure :ARG1 possible :polarity - :ARG1 deploy :ARG0 they :ARG1 they :manner thing :polarity - :ARG1-of guarantee :source contract :ARG1-of sign :ARG0 they :ARG2 we
# sure :ARG1 possible :polarity - :ARG1 deploy :ARG0 they :ARG1 they :manner thing :polarity - :ARG1-of guarantee :source contract :ARG1-of sign :ARG0 they :ARG2 we
# 0 sure
# 1 :ARG1
# 2 possible
# 3 :polarity
# 4
# 5 -
# 6 :ARG1
# 7 deploy
# 8 :ARG0
# 9 they
# 10 :ARG1
# 11 they
# 12 :manner
# 13 thing
# 14 :polarity
# 15
# 16 -
# 17 :ARG1-of
# 18 guarantee
# 19 :source
# 20 contract
# 21 :ARG1-of
# 22 sign
# 23 :ARG0
# 24 they
# 25 :ARG2
# 26 we
# ERROR
# hear :ARG0 i :ARG1 and :op1 serious :ARG1 government-organization :ARG0-of govern :ARG2 matter :mod this :degree very :op2 agree :ARG0 government-organization :ARG1 allocate :ARG0 government-organization :ARG1 thing :ARG2-of fund :ARG0 government-organization :ARG1 compensate-01 :ARG2 compensate :ARG0 government-organization :ARG1 money :ARG2 person :ARG0-of use :ARG1 money :poss person :time date-entity :mod that :dayperiod night :ARG1-of instead-of :ARG0-of study :manner prompt :ARG2 person :ARG0-of have-org-role :ARG1 consulate :ARG0-of have-rel-role :ARG1 i :ARG2 friend
# hear :ARG0 i :ARG1 and :op1 serious :ARG1 government-organization :ARG0-of govern :ARG2 matter :mod this :degree very :op2 agree :ARG0 government-organization :ARG1 allocate :ARG0 government-organization :ARG1 thing :ARG2-of fund :ARG0 government-organization :ARG1 compensate-01 :ARG2 compensate :ARG0 government-organization :ARG1 money :ARG2 person :ARG0-of use :ARG1 money :poss person :time date-entity :mod that :dayperiod night :ARG1-of instead-of :ARG0-of study :manner prompt :ARG2 person :ARG0-of have-org-role :ARG1 consulate :ARG0-of have-rel-role :ARG1 i :ARG2 friend
# 0 hear
# 1 :ARG0
# 2
# 3 i
# 4 :ARG1
# 5 and
# 6 :op1
# 7 serious
# 8 :ARG1
# 9 government
# 10 -
# 11 organiz
# 12 ation
# 13 :ARG0-of
# 14 govern
# 15 :ARG2
# 16 matter
# 17 :mod
# 18 this
# 19 :degree
# 20 very
# 21 :op2
# 22 agree
# 23 :ARG0
# 24 government
# 25 -
# 26 organiz
# 27 ation
# 28 :ARG1
# 29 allocate
# 30 :ARG0
# 31 government
# 32 -
# 33 organiz
# 34 ation
# 35 :ARG1
# 36 thing
# 37 :ARG2-of
# 38 fund
# 39 :ARG0
# 40 government
# 41 -
# 42 organiz
# 43 ation
# 44 :ARG1
# 45 compensate
# 46 -01
# 47 :ARG2
# 48 compensate
# 49 :ARG0
# 50 government
# 51 -
# 52 organiz
# 53 ation
# 54 :ARG1
# 55 money
# 56 :ARG2
# 57 person
# 58 :ARG0-of
# 59 use
# 60 :ARG1
# 61 money
# 62 :poss
# 63 person
# 64 :time
# 65 date
# 66 -
# 67 ent
# 68 ity
# 69 :mod
# 70 that
# 71 :dayperiod
# 72 night
# 73 :ARG1-of
# 74 instead
# 75 -
# 76 of
# 77 :ARG0-of
# 78 study
# 79 :manner
# 80 prompt
# 81 :ARG2
# 82 person
# 83 :ARG0-of
# 84 have
# 85 -
# 86 org
# 87 -
# 88 rol
# 89 e
# 90 :ARG1
# 91 cons
# 92 ulate
# 93 :ARG0-of
# 94 have
# 95 -
# 96 re
# 97 l
# 98 -
# 99 rol
# 100 e
# 101 :ARG1
# 102
# 103 i
# 104 :ARG2
# 105 friend
# ERROR
# contrast :ARG1 go-back :ARG1 i :purpose check-out :ARG0 i :ARG1 relay :ARG2 torch :time date-entity :dayperiod afternoon :mod yesterday :ARG2 possible :polarity - :ARG1 see :ARG1 and :op1 flame :mod even :op2 guy :mod let-alone :ARG0-of carry :ARG1 torch :mod practical
# contrast :ARG1 go-back :ARG1 i :purpose check-out :ARG0 i :ARG1 relay :ARG2 torch :time date-entity :dayperiod afternoon :mod yesterday :ARG2 possible :polarity - :ARG1 see :ARG1 and :op1 flame :mod even :op2 guy :mod let-alone :ARG0-of carry :ARG1 torch :mod practical
# 0 contrast
# 1 :ARG1
# 2 go
# 3 -
# 4 back
# 5 :ARG1
# 6
# 7 i
# 8 :purpose
# 9 check
# 10 -
# 11 out
# 12 :ARG0
# 13
# 14 i
# 15 :ARG1
# 16 relay
# 17 :ARG2
# 18 torch
# 19 :time
# 20 date
# 21 -
# 22 ent
# 23 ity
# 24 :dayperiod
# 25 afternoon
# 26 :mod
# 27 yesterday
# 28 :ARG2
# 29 possible
# 30 :polarity
# 31
# 32 -
# 33 :ARG1
# 34 see
# 35 :ARG1
# 36 and
# 37 :op1
# 38 flame
# 39 :mod
# 40 even
# 41 :op2
# 42 guy
# 43 :mod
# 44 let
# 45 -
# 46 al
# 47 one
# 48 :ARG0-of
# 49 carry
# 50 :ARG1
# 51 torch
# 52 :mod
# 53 practical
# ERROR
# multi-sentence :snt1 be-located-at :ARG1 person :ARG1-of have-quant :ARG2 many :ARG3 so :ARG6 frighten :ARG0 be-located-at-91 :ARG2 there :snt2 climb :ARG0 person :quant some :ARG1 onto :op1 roof :part-of bus :mod even
# multi-sentence :snt1 be-located-at :ARG1 person :ARG1-of have-quant :ARG2 many :ARG3 so :ARG6 frighten :ARG0 be-located-at-91 :ARG2 there :snt2 climb :ARG0 person :quant some :ARG1 onto :op1 roof :part-of bus :mod even
# 0 multi
# 1 -
# 2 sent
# 3 ence
# 4 :snt1
# 5 be
# 6 -
# 7 loc
# 8 ated
# 9 -
# 10 at
# 11 :ARG1
# 12 person
# 13 :ARG1-of
# 14 have
# 15 -
# 16 quant
# 17 :ARG2
# 18 many
# 19 :ARG3
# 20 so
# 21 :ARG6
# 22
# 23 f
# 24 right
# 25 en
# 26 :ARG0
# 27 be
# 28 -
# 29 loc
# 30 ated
# 31 -
# 32 at
# 33 -
# 34 91
# 35 :ARG2
# 36 there
# 37 :snt2
# 38 climb
# 39 :ARG0
# 40 person
# 41 :quant
# 42 some
# 43 :ARG1
# 44 onto
# 45 :op1
# 46 roof
# 47 :part-of
# 48 bus
# 49 :mod
# 50 even
# ERROR
# contrast :ARG1 head :ARG0 i :ARG1 center :mod activity :ARG1-of straight :ARG2 and :op1 control :ARG1 traffic :mod in-fact :ARG1-of actual :time date-entity :time 16:00 :mod early :op2 start :ARG0 they :ARG1 limit :ARG1 crowd :ARG0-of enter :ARG1 center :mod sport :time already
# contrast :ARG1 head :ARG0 i :ARG1 center :mod activity :ARG1-of straight :ARG2 and :op1 control :ARG1 traffic :mod in-fact :ARG1-of actual :time date-entity :time 16:00 :mod early :op2 start :ARG0 they :ARG1 limit :ARG1 crowd :ARG0-of enter :ARG1 center :mod sport :time already
# 0 contrast
# 1 :ARG1
# 2 head
# 3 :ARG0
# 4
# 5 i
# 6 :ARG1
# 7 center
# 8 :mod
# 9 activity
# 10 :ARG1-of
# 11 straight
# 12 :ARG2
# 13 and
# ...
# reason :quant 1 :ARG0-of cause :ARG1 save :ARG1 or :op1 person :quant number :mod great :ARG1-of bury :ARG2 debris :op2 person :quant number :ARG1-of trap :ARG2 debris :location area :ARG1-of hit :ARG0 earthquake :wiki 2008_Sichuan_earthquake :name name :op1 Wenchuan :op2 Earthquake :ARG2 or :op1 bury-01 :op2 trap-01 :ARG1-of important :domain and :op1 full :ARG1 person :ARG2 hopeful :op2 believe :ARG0 person :ARG1 come :ARG1 military :wiki People's_Liberation_Army :name name :op1 PLA :purpose rescue :ARG0 military :ARG1 person :ARG1-of firm
# 0 reason
# 1 :quant
# 2 1
# 3 :ARG0-of
# 4 cause
# 5 :ARG1
# 6 save
# 7 :ARG1
# 8 or
# 9 :op1
# 10 person
# 11 :quant
# 12 number
# 13 :mod
# 14 great
# 15 :ARG1-of
# 16
# 17 bury
# 18 :ARG2
# 19 debris
# 20 :op2
# 21 person
# 22 :quant
# 23 number
# 24 :ARG1-of
# 25 trap
# 26 :ARG2
# 27 debris
# 28 :location
# 29 area
# 30 :ARG1-of
# 31 hit
# 32 :ARG0
# 33 earthquake
# 46 :name
# 47 name
# 48 :op1
# 49 We
# 50 n
# 51 chu
# 52 an
# 53 :op2
# 54 Earth
# 55 qua
# 56 ke
# 57 :ARG2
# 58 or
# 59 :op1
# 60
# 61 bury
# 62 -01
# 63 :op2
# 64 trap
# 65 -01
# 66 :ARG1-of
# 67 important
# 68 :domain
# 69 and
# 70 :op1
# 71 full
# 72 :ARG1
# 73 person
# 74 :ARG2
# 75 hopeful
# 76 :op2
# 77 believe
# 78 :ARG0
# 79 person
# 80 :ARG1
# 81 come
# 82 :ARG1
# 83 military
# 95 :name
# 96 name
# 97 :op1
# 98 PLA
# 99 :purpose
# 100 rescue
# 101 :ARG0
# 102 military
# 103 :ARG1
# 104 person
# 105 :ARG1-of
# 106 firm
# ERROR
# set-up :ARG1 tent :quant multiple :op1 1000 :ARG1-of stretch :ARG2 multiple :op1 distance-quantity :quant 1 :unit mile :ARG0-of contain :ARG1 and :op1 toilet :ARG1-of public :op2 shop :op3 school :mod primary :op4 middle-school :time soon :purpose settle :ARG1 victim
# set-up :ARG1 tent :quant multiple :op1 1000 :ARG1-of stretch :ARG2 multiple :op1 distance-quantity :quant 1 :unit mile :ARG0-of contain :ARG1 and :op1 toilet :ARG1-of public :op2 shop :op3 school :mod primary :op4 middle-school :time soon :purpose settle :ARG1 victim
# 0 set
# 1 -
# 2 up
# 3 :ARG1
# 4 tent
# 5 :quant
# 6 multiple
# 7 :op1
# 8 1000
# 9 :ARG1-of
# 10 stretch
# 11 :ARG2
# 12 multiple
# 13 :op1
# 14 distance
# 15 -
# 16 quant
# 17 ity
# 18 :quant
# 19 1
# 20 :unit
# 21 mile
# 22 :ARG0-of
# 23 contain
# 24 :ARG1
# 25 and
# 26 :op1
# 27 toilet
# 28 :ARG1-of
# 29 public
# 30 :op2
# 31 shop
# 32 :op3
# 33 school
# 34 :mod
# 35 primary
# 36 :op4
# 37 middle
# 38 -
# 39 school
# 40 :time
# 41 soon
# 42 :purpose
# 43 settle
# 44 :ARG1
# 45 victim
# ERROR
# have :ARG0 person :mod that :ARG1-of displace :ARG0 disaster :quant or :op1 multiple :op1 10000 :op2 multiple :op1 1000000 :mod even :ARG1 home :purpose shelter :ARG1 person :ARG3 and :op1 wind :op2 rain :manner gradual
# have :ARG0 person :mod that :ARG1-of displace :ARG0 disaster :quant or :op1 multiple :op1 10000 :op2 multiple :op1 1000000 :mod even :ARG1 home :purpose shelter :ARG1 person :ARG3 and :op1 wind :op2 rain :manner gradual
# 0 have
# 1 :ARG0
# 2 person
# 3 :mod
# 4 that
# 5 :ARG1-of
# 6 dis
# 7 place
# 8 :ARG0
# 9 disaster
# 10 :quant
# 11 or
# 12 :op1
# 13 multiple
# 14 :op1
# 15 10
# 16 000
# 17 :op2
# 18 multiple
# 19 :op1
# 20 1000
# 21 000
# 22 :mod
# 23 even
# 24 :ARG1
# 25 home
# 26 :purpose
# 27 shelter
# 28 :ARG1
# 29 person
# 30 :ARG3
# 31 and
# 32 :op1
# 33 wind
# 34 :op2
# 35 rain
# 36 :manner
# 37 gradual
# ERROR
# recommend :ARG1 set-up :ARG0 government-organization :ARG0-of govern :ARG1 tent :location amr-unknown :condition put :ARG1 everything :ARG2 market :ARG0-of cause :ARG1 sell :ARG1 land :mod all :ARG2 or :op1 syndicate :op2 person :ARG0-of own :ARG1 farm
# recommend :ARG1 set-up :ARG0 government-organization :ARG0-of govern :ARG1 tent :location amr-unknown :condition put :ARG1 everything :ARG2 market :ARG0-of cause :ARG1 sell :ARG1 land :mod all :ARG2 or :op1 syndicate :op2 person :ARG0-of own :ARG1 farm
# 0 recommend
# 1 :ARG1
# 2 set
# 3 -
# 4 up
# 5 :ARG0
# 6 government
# 7 -
# 8 organiz
# 9 ation
# 10 :ARG0-of
# 11 govern
# 12 :ARG1
# 13 tent
# 14 :location
# 15 am
# 16 r
# 17 -
# 18 un
# 19 known
# 20 :condition
# 21 put
# 22 :ARG1
# 23 everything
# 24 :ARG2
# 25 market
# 26 :ARG0-of
# 27 cause
# 28 :ARG1
# 29 sell
# 30 :ARG1
# 31 land
# 32 :mod
# 33 all
# 34 :ARG2
# 35 or
# 36 :op1
# 37 syndicat
# 38 e
# 39 :op2
# 40 person
# 41 :ARG0-of
# 42 own
# 43 :ARG1
# 44 farm
# ERROR
# expropriate :ARG0 they :ARG1 land :polarity amr-unknown :manner on-the-spot
# expropriate :ARG0 they :ARG1 land :polarity amr-unknown :manner on-the-spot
# 0 ex
# 1 pro
# 2 pri
# 3 ate
# 4 :ARG0
# 5 they
# 6 :ARG1
# 7 land
# 8 :polarity
# 9 am
# 10 r
# 11 -
# 12 un
# 13 known
# 14 :manner
# 15 on
# 16 -
# 17 the
# 18 -
# 19 s
# 20 pot
# ERROR
# possible :ARG1 override :ARG0 government-organization :ARG0-of govern :mod even :ARG1 market
# possible :ARG1 override :ARG0 government-organization :ARG0-of govern :mod even :ARG1 market
# 0 possible
# 1 :ARG1
# 2 over
# 3 rid
# 4 e
# 5 :ARG0
# 6 government
# 7 -
# 8 organiz
# 9 ation
# 10 :ARG0-of
# 11 govern
# 12 :mod
# 13 even
# 14 :ARG1
# 15 market
# ERROR
# contrast :ARG1 test :ARG0 support :ARG0 we :ARG1 area :ARG1-of hit :ARG0 disaster :ARG1 competent :ARG1 we :ARG2 try :ARG1 capable :ARG1 government-organization :ARG0-of govern :ARG2 rule :ARG0 government-organization :mod also
# contrast :ARG1 test :ARG0 support :ARG0 we :ARG1 area :ARG1-of hit :ARG0 disaster :ARG1 competent :ARG1 we :ARG2 try :ARG1 capable :ARG1 government-organization :ARG0-of govern :ARG2 rule :ARG0 government-organization :mod also
# 0 contrast
# 1 :ARG1
# 2 test
# 3 :ARG0
# 4 support
# 5 :ARG0
# 6 we
# 7 :ARG1
# 8 area
# 9 :ARG1-of
# 10 hit
# 11 :ARG0
# 12 disaster
# 13 :ARG1
# 14 competent
# 15 :ARG1
# 16 we
# 17 :ARG2
# 18 try
# 19 :ARG1
# 20 capable
# 21 :ARG1
# 22 government
# 23 -
# 24 organiz
# 25 ation
# 26 :ARG0-of
# 27 govern
# 28 :ARG2
# 29 rule
# 30 :ARG0
# 31 government
# 32 -
# 33 organiz
# 34 ation
# 35 :mod
# 36 also
# ERROR
# show :ARG0 and :op1 person :ARG0-of work :op2 person :ARG0-of farm :ARG2-of found :ARG0-of rule :ARG1 support :ARG1 government-organization :ARG0-of govern :manner staunch :time moment :ARG1-of critical
# show :ARG0 and :op1 person :ARG0-of work :op2 person :ARG0-of farm :ARG2-of found :ARG0-of rule :ARG1 support :ARG1 government-organization :ARG0-of govern :manner staunch :time moment :ARG1-of critical
# 0 show
# 1 :ARG0
# 2 and
# 3 :op1
# 4 person
# 5 :ARG0-of
# 6 work
# 7 :op2
# 8 person
# 9 :ARG0-of
# 10 farm
# 11 :ARG2-of
# 12 found
# 13 :ARG0-of
# 14 rule
# 15 :ARG1
# 16 support
# 17 :ARG1
# 18 government
# 19 -
# 20 organiz
# 21 ation
# 22 :ARG0-of
# 23 govern
# 24 :manner
# 25 stau
# 26 nch
# 27 :time
# 28 moment
# 29 :ARG1-of
# 30 critical
# ERROR
# have :ARG0 government-organization :ARG0-of govern :ARG1 power :mod amr-unknown :condition market :ARG1 everything :ARG0-of cause :ARG1 and :op1 control :ARG0 market :ARG1 and :op1 fate :poss person :ARG0-of work :op2 fate :poss person :ARG0-of farm :op2 or :op1 count :ARG0 and :ARG1 government-organization :op2 rely :ARG0 and :ARG1 government-organization :manner walk :ARG0 and :destination path :mod find :ARG1 market :mod so-called :ARG1-of instead-of :ARG2 find :ARG1 mayor :ARG1-of mean :ARG2 government-organization :time no-longer
# have :ARG0 government-organization :ARG0-of govern :ARG1 power :mod amr-unknown :condition market :ARG1 everything :ARG0-of cause :ARG1 and :op1 control :ARG0 market :ARG1 and :op1 fate :poss person :ARG0-of work :op2 fate :poss person :ARG0-of farm :op2 or :op1 count :ARG0 and :ARG1 government-organization :op2 rely :ARG0 and :ARG1 government-organization :manner walk :ARG0 and :destination path :mod find :ARG1 market :mod so-called :ARG1-of instead-of :ARG2 find :ARG1 mayor :ARG1-of mean :ARG2 government-organization :time no-longer
# 0 have
# 1 :ARG0
# 2 government
# 3 -
# 4 organiz
# 5 ation
# 6 :ARG0-of
# 7 govern
# 8 :ARG1
# 9 power
# 10 :mod
# 11 am
# 12 r
# 13 -
# 14 un
# 15 known
# 16 :condition
# 17 market
# 18 :ARG1
# 19 everything
# 20 :ARG0-of
# 21 cause
# 22 :ARG1
# 23 and
# 24 :op1
# 25 control
# 26 :ARG0
# 27 market
# 28 :ARG1
# 29 and
# 30 :op1
# 31 fate
# 32 :poss
# 33 person
# 34 :ARG0-of
# 35 work
# 36 :op2
# 37 fate
# 38 :poss
# 39 person
# 40 :ARG0-of
# 41 farm
# 42 :op2
# 43 or
# 44 :op1
# 45 count
# 46 :ARG0
# 47 and
# 48 :ARG1
# 49 government
# 50 -
# 51 organiz
# 52 ation
# 53 :op2
# 54
# 55 rely
# 56 :ARG0
# 57 and
# 58 :ARG1
# 59 government
# 60 -
# 61 organiz
# 62 ation
# 63 :manner
# 64 walk
# 65 :ARG0
# 66 and
# 67 :destination
# 68 path
# 69 :mod
# 70 find
# 71 :ARG1
# 72 market
# 73 :mod
# 74 so
# 75 -
# 76 called
# 77 :ARG1-of
# 78 instead
# 79 -
# 80 of
# 81 :ARG2
# 82 find
# 83 :ARG1
# 84 mayor
# 85 :ARG1-of
# 86 mean
# 87 :ARG2
# 88 government
# 89 -
# 90 organiz
# 91 ation
# 92 :time
# 93 no
# 94 -
# 95 long
# 96 er
# ERROR
# come :polarity - :ARG1 hyperinflation :time after :op1 catastrophe :ARG1-of expect :ARG0 foreign :mod either
# come :polarity - :ARG1 hyperinflation :time after :op1 catastrophe :ARG1-of expect :ARG0 foreign :mod either
# 0 come
# 1 :polarity
# 2
# 3 -
# 4 :ARG1
# 5 hyper
# 6 in
# 7 f
# 8 lation
# 9 :time
# 10 after
# 11 :op1
# 12 catastrophe
# 13 :ARG1-of
# 14 expect
# 15 :ARG0
# 16 foreign
# 17 :mod
# 18 either
# ERROR
# control :ARG0 government-organization :ARG0-of govern :ARG1 and :op1 capital :mod human :op2 capital :mod finance :op3 energy :op4 resource
# control :ARG0 government-organization :ARG0-of govern :ARG1 and :op1 capital :mod human :op2 capital :mod finance :op3 energy :op4 resource
# 0 control
# 1 :ARG0
# 2 government
# 3 -
# 4 organiz
# 5 ation
# 6 :ARG0-of
# 7 govern
# 8 :ARG1
# 9 and
# 10 :op1
# 11 capital
# 12 :mod
# 13 human
# 14 :op2
# 15 capital
# 16 :mod
# 17 finance
# 18 :op3
# 19 energy
# 20 :op4
# 21 resource
# ERROR
# exemplify :ARG0 have :ARG0 value :mod seize :ARG1 pleasure :mod moment :ARG1 history :ARG1-of long :mod also
# exemplify :ARG0 have :ARG0 value :mod seize :ARG1 pleasure :mod moment :ARG1 history :ARG1-of long :mod also
# 0
# 1 exe
# 2 mp
# 3 l
# 4 ify
# 5 :ARG0
# 6 have
# 7 :ARG0
# 8 value
# 9 :mod
# 10 se
# 11 ize
# 12 :ARG1
# 13 pleasure
# 14 :mod
# 15 moment
# 16 :ARG1
# 17 history
# 18 :ARG1-of
# 19 long
# 20 :mod
# 21 also
# ERROR
# multi-sentence :snt1 and :op1 sing :mode imperative :ARG0 you :ARG1 song :time have :ARG0 you :ARG1 wine :op2 seize :mode imperative :ARG0 you :ARG1 day :ARG1-of cause :ARG0 short :ARG1 life :snt2 think :ARG0 person :mod some :ARG1 recommend :ARG1 and :op1 satisfy :ARG0 we :ARG1 we :op2 die :ARG1 we :time contemporary
# multi-sentence :snt1 and :op1 sing :mode imperative :ARG0 you :ARG1 song :time have :ARG0 you :ARG1 wine :op2 seize :mode imperative :ARG0 you :ARG1 day :ARG1-of cause :ARG0 short :ARG1 life :snt2 think :ARG0 person :mod some :ARG1 recommend :ARG1 and :op1 satisfy :ARG0 we :ARG1 we :op2 die :ARG1 we :time contemporary
# 0 multi
# 1 -
# 2 sent
# 3 ence
# 4 :snt1
# 5 and
# 6 :op1
# 7 sing
# 8 :mode
# 9 imperative
# 10 :ARG0
# 11 you
# 12 :ARG1
# 13 song
# 14 :time
# 15 have
# 16 :ARG0
# 17 you
# 18 :ARG1
# 19 wine
# 20 :op2
# 21 se
# 22 ize
# 23 :mode
# 24 imperative
# 25 :ARG0
# 26 you
# 27 :ARG1
# 28 day
# 29 :ARG1-of
# 30 cause
# 31 :ARG0
# 32 short
# 33 :ARG1
# 34 life
# 35 :snt2
# 36 think
# 37 :ARG0
# 38 person
# 39 :mod
# 40 some
# 41 :ARG1
# 42 recommend
# 43 :ARG1
# 44 and
# 45 :op1
# 46 satisfy
# 47 :ARG0
# 48 we
# 49 :ARG1
# 50 we
# 51 :op2
# 52 die
# 53 :ARG1
# 54 we
# 55 :time
# 56 contemporary
# ERROR
# have-degree :ARG1 go :ARG0 person :mod some :ARG1 road :ARG2 far :ARG3 so :ARG6 cause :ARG1 know :polarity - :ARG0 person :ARG1 thing :manner-of or :op1 eat :ARG0 person :op2 play :ARG0 person
# have-degree :ARG1 go :ARG0 person :mod some :ARG1 road :ARG2 far :ARG3 so :ARG6 cause :ARG1 know :polarity - :ARG0 person :ARG1 thing :manner-of or :op1 eat :ARG0 person :op2 play :ARG0 person
# 0 have
# 1 -
# 2 degree
# 3 :ARG1
# 4 go
# 5 :ARG0
# 6 person
# 7 :mod
# 8 some
# 9 :ARG1
# 10 road
# 11 :ARG2
# 12 far
# 13 :ARG3
# 14 so
# 15 :ARG6
# 16 cause
# 17 :ARG1
# 18 know
# 19 :polarity
# 20
# 21 -
# 22 :ARG0
# 23 person
# 24 :ARG1
# 25 thing
# 26 :manner-of
# 27 or
# 28 :op1
# 29
# 30 eat
# 31 :ARG0
# 32 person
# 33 :op2
# 34 play
# 35 :ARG0
# 36 person
# ERROR
# and :op2 and :op1 take :ARG0 other :ARG1 picture :mod nude :op2 flaunt :ARG0 other :ARG1 picture :medium online
# and :op2 and :op1 take :ARG0 other :ARG1 picture :mod nude :op2 flaunt :ARG0 other :ARG1 picture :medium online
# 0 and
# 1 :op2
# 2 and
# 3 :op1
# 4 take
# 5 :ARG0
# 6 other
# 7 :ARG1
# 8 picture
# 9 :mod
# 10 nu
# 11 de
# 12 :op2
# 13 fla
# 14 un
# 15 t
# 16 :ARG0
# 17 other
# 18 :ARG1
# 19 picture
# 20 :medium
# 21 online
# ERROR
# exemplify :ARG0 possible :ARG1 trace :ARG1 pursue :ARG1 and :op1 title :mod office :op2 level :mod office :ARG2 day :mod old :mod also :mod another
# exemplify :ARG0 possible :ARG1 trace :ARG1 pursue :ARG1 and :op1 title :mod office :op2 level :mod office :ARG2 day :mod old :mod also :mod another
# 0
# 1 exe
# 2 mp
# 3 l
# 4 ify
# 5 :ARG0
# 6 possible
# 7 :ARG1
# 8 trace
# 9 :ARG1
# 10 pursue
# 11 :ARG1
# 12 and
# 13 :op1
# 14 title
# 15 :mod
# 16 office
# 17 :op2
# 18 level
# 19 :mod
# 20 office
# 21 :ARG2
# 22 day
# 23 :mod
# 24 old
# 25 :mod
# 26 also
# 27 :mod
# 28 another
# ERROR
# distinguish :ARG0 person :wiki - :name name :op1 Zhou :op2 Li :ARG1 order :ARG1 and :op1 hierarchy :op2 nobility :manner construct :ARG0 person :ARG1 structure :mod organize :ARG1 society :ARG1-of resemble :ARG2 pyramid :time ancient
# distinguish :ARG0 person :wiki - :name name :op1 Zhou :op2 Li :ARG1 order :ARG1 and :op1 hierarchy :op2 nobility :manner construct :ARG0 person :ARG1 structure :mod organize :ARG1 society :ARG1-of resemble :ARG2 pyramid :time ancient
# 0 distinguish
# 1 :ARG0
# 2 person
# 6 :name
# 7 name
# 8 :op1
# 9 Z
# 10 hou
# 11 :op2
# 12 Li
# 13 :ARG1
# 14 order
# 15 :ARG1
# 16 and
# 17 :op1
# 18 hierarchy
# 19 :op2
# 20 no
# 21 b
# 22 ility
# 23 :manner
# 24 construct
# 25 :ARG0
# 26 person
# 27 :ARG1
# 28 structure
# 29 :mod
# 30 organize
# 31 :ARG1
# 32 society
# 33 :ARG1-of
# 34
# 35 resemble
# 36 :ARG2
# 37 pyramid
# 38 :time
# 39 ancient
# ERROR
# multi-sentence :snt1 wear :ARG0 person :wiki Son_of_Heaven :name name :op1 Son :op2 of :op3 Heaven :ARG1 clothes :ARG1-of differ :ARG2 clothes :ARG1-of wear :ARG0 other :snt2 symbolize :ARG1 and :op1 color :mod door :op2 number :quant-of caldron :ARG1-of use :ARG2 meal :mod all :purpose distinguish :ARG0 and :ARG1 and :op1 hierarchy :consist-of person :op2 nobility :poss person
# multi-sentence :snt1 wear :ARG0 person :wiki Son_of_Heaven :name name :op1 Son :op2 of :op3 Heaven :ARG1 clothes :ARG1-of differ :ARG2 clothes :ARG1-of wear :ARG0 other :snt2 symbolize :ARG1 and :op1 color :mod door :op2 number :quant-of caldron :ARG1-of use :ARG2 meal :mod all :purpose distinguish :ARG0 and :ARG1 and :op1 hierarchy :consist-of person :op2 nobility :poss person
# 0 multi
# 1 -
# 2 sent
# 3 ence
# 4 :snt1
# 5 wear
# 6 :ARG0
# 7 person
# 16 :name
# 17 name
# 18 :op1
# 19 Son
# 20 :op2
# 21 of
# 22 :op3
# 23 Heaven
# 24 :ARG1
# 25 clothes
# 26 :ARG1-of
# 27 differ
# 28 :ARG2
# 29 clothes
# 30 :ARG1-of
# 31 wear
# 32 :ARG0
# 33 other
# 34 :snt2
# 35 symbolize
# 36 :ARG1
# 37 and
# 38 :op1
# 39 color
# 40 :mod
# 41 door
# 42 :op2
# 43 number
# 44 :quant-of
# 45
# 46 cal
# 47 dron
# 48 :ARG1-of
# 49 use
# 50 :ARG2
# 51 meal
# 52 :mod
# 53 all
# 54 :purpose
# 55 distinguish
# 56 :ARG0
# 57 and
# 58 :ARG1
# 59 and
# 60 :op1
# 61 hierarchy
# 62 :consist-of
# 63 person
# 64 :op2
# 65 no
# 66 b
# 67 ility
# 68 :poss
# 69 person
# ERROR
# contrast :ARG2 establish :ARG0 it :ARG1 system :ARG0-of value :ARG1 life :ARG1-of conform :ARG2 level :mod office :ARG0-of trigger :ARG1 contention :ARG1-of contrary :ARG0-of destabilize :ARG1 society :ARG1-of contrary-01 :mod also :mod simultaneous
# contrast :ARG2 establish :ARG0 it :ARG1 system :ARG0-of value :ARG1 life :ARG1-of conform :ARG2 level :mod office :ARG0-of trigger :ARG1 contention :ARG1-of contrary :ARG0-of destabilize :ARG1 society :ARG1-of contrary-01 :mod also :mod simultaneous
# 0 contrast
# 1 :ARG2
# 2 establish
# 3 :ARG0
# 4 it
# 5 :ARG1
# 6 system
# 7 :ARG0-of
# 8 value
# 9 :ARG1
# 10 life
# 11 :ARG1-of
# 12 conform
# 13 :ARG2
# 14 level
# 15 :mod
# 16 office
# 17 :ARG0-of
# 18 trigger
# 19 :ARG1
# 20 contention
# 21 :ARG1-of
# 22 contrary
# 23 :ARG0-of
# 24 de
# 25 stabil
# 26 ize
# 27 :ARG1
# 28 society
# 29 :ARG1-of
# 30 contrary
# 31 -01
# 32 :mod
# 33 also
# 34 :mod
# 35 simultaneous
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 82
#      79 batch_dict_json = json.dumps(batch_dict)
#      81 # Write the JSON data to the file
# ---> 82 with open(file_path, 'w') as file:
#      83     file.write(batch_dict_json)
#      85 # Append the processed batch to the dictionary
#
# File /opt/anaconda3/envs/gr/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './custom_datasets_batches/0.json'

# %%
# # Initialize and run the model
# config = Config.from_name('stablelm-base-alpha-3b')  # Adjust according to your config
# model = GPT(config,batches_dict["eig_vecs"].size(-1))
# output = model(batches_dict)
# print(output)

# %%
# Generate positions for a tree layout
pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
#edge_labels = nx.get_edge_attributes(G, 'label')
plt.figure(figsize=(120*2, 80*2))  # You can adjust the size as needed

# Draw the graph
#pos = nx.spring_layout(G, center=[0.5, 0.5])  
#nx.draw(G, pos, with_labels=True, labels = labels_dict, node_color='skyblue', node_size=10000, edge_color='k', linewidths=1, font_size=100)
nx.draw_networkx_nodes(G, pos, node_color='skyblue', node_size=1000)

# Draw edges with arrows
nx.draw_networkx_edges(G, pos, edge_color='gray', arrowstyle='-|>', arrowsize=150)

# Draw labels
nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=150)

plt.show()

# %%
tokenizer.decode(AMR["target_labels"])

# %%
eigv = batches_dict["eig_vecs"][0][0]

# %%
eigv.shape

# %%
eigv[1]

# %%
batches_dict.keys()

# %%
for key in batches_dict.keys():
    print(key, batches_dict[key][0][0])

# %%
batches_dict

# %%
# Get the edge list
edge_list = nx.generate_edgelist(G, data=False)

# Convert edge list to a single string
edge_list_str = "\n".join(edge_list)

print(edge_list_str)

# %%
G

# %%
import numpy as np

def pad_and_concat_eigenvectors(eigenvectors, max_seq_len):
    """
    Pad and concatenate the real and imaginary parts of eigenvectors.

    Parameters:
    eigenvectors (list of list of complex): A square matrix (m by m) of complex-valued eigenvectors.
    max_seq_len (int): The maximum sequence length.

    Returns:
    np.ndarray: A vector with real parts from 0 to max_seq_len - 1 and imaginary parts from max_seq_len to max_seq_len * 2 - 1.
    """
    m = len(eigenvectors)
    
    # Initialize the padded vector with complex zeros
    padded_vector = np.zeros((max_seq_len,max_seq_len * 2,), dtype=complex)
    
    for i in range(m):
        real_part = [e.real for e in eigenvectors[i]]
        imag_part = [e.imag for e in eigenvectors[i]]
        
        # Place real part in the first half
        padded_vector[i][:m] = real_part
        # Place imaginary part in the second half
        padded_vector[i][max_seq_len:max_seq_len + m]  = imag_part
    
    return padded_vector.astype(np.float32)

# Example usage
eigenvectors = [
    [1+2j, 3+4j],
    [5+6j, 7+8j]
]
max_seq_len = 3

result = pad_and_concat_eigenvectors(eigenvectors, max_seq_len)
print(result)
# Out:
# [[1. 3. 0. 2. 4. 0.]
#  [5. 7. 0. 6. 8. 0.]
#  [0. 0. 0. 0. 0. 0.]]
# /var/folders/xg/f_s_mvhd3td4136d5b4238r40000gn/T/ipykernel_31572/2667897804.py:28: ComplexWarning: Casting complex values to real discards the imaginary part
#   return padded_vector.astype(np.float32)

# %%
from transformers import T5Tokenizer
from init_tokenizer import CustomT5Tokenizer

tokenizer = T5Tokenizer.from_pretrained("t5-base")
tokenizer = CustomT5Tokenizer(tokenizer)

# %%
ids = tokenizer.encode("and :op1 believe :ARG0 person :ARG0-of have-org-role :ARG1 company :wiki - :name name :op1 IM :mod country :wiki United_States :name name :op1 United :op2 States :ARG2 officer :mod executive :mod chief :ARG1 capable :ARG1 person :ARG1-of employ :ARG0 company :mod each :ARG2 innovate :ARG0 person :op2 formulate :ARG0 officer :mod executive :mod chief :ARG1 countermeasure :mod strategy :purpose innovate :topic industry :time after :op1 invent :ARG0 company :ARG0-of compete :ARG1 company :ARG1 machine :ARG0-of wash :ARG1-of load :mod front")
for id in ids:
    print(tokenizer.decode([id]))
# Out:
# and
# :op1
# believe
# :ARG0
# person
# :ARG0-of
# have-org-role
# :ARG1
# company
# :wiki
# -
# :name
# name
# :op1
# IM
# :mod
# country
# :wiki
# United_States
# :name
# name
# :op1
# United
# :op2
# States
# :ARG2
# officer
# :mod
# executive
# :mod
# chief
# :ARG1
# capable
# :ARG1
# person
# :ARG1-of
# employ
# :ARG0
# company
# :mod
# each
# :ARG2
# innovate
# :ARG0
# person
# :op2
# formulate
# :ARG0
# officer
# :mod
# executive
# :mod
# chief
# :ARG1
# countermeasure
# :mod
# strategy
# :purpose
# innovate
# :topic
# industry
# :time
# after
# :op1
# invent
# :ARG0
# company
# :ARG0-of
# compete
# :ARG1
# company
# :ARG1
# machine
# :ARG0-of
# wash
# :ARG1-of
# load
# :mod
# front

# %%
ids
# Out:
# [32100,
#  32101,
#  32102,
#  32103,
#  32104,
#  32105,
#  32106,
#  32107,
#  32108,
#  32109,
#  32110,
#  32111,
#  32112,
#  32101,
#  32113,
#  32114,
#  32115,
#  32109,
#  32116,
#  32111,
#  32112,
#  32101,
#  32117,
#  32118,
#  32119,
#  32120,
#  32121,
#  32114,
#  32122,
#  32114,
#  32123,
#  32107,
#  32124,
#  32107,
#  32104,
#  32125,
#  32126,
#  32103,
#  32108,
#  32114,
#  32127,
#  32120,
#  32128,
#  32103,
#  32104,
#  32118,
#  32129,
#  32103,
#  32121,
#  32114,
#  32122,
#  32114,
#  32123,
#  32107,
#  32130,
#  32114,
#  32131,
#  32132,
#  32128,
#  32133,
#  32134,
#  32135,
#  32136,
#  32101,
#  32137,
#  32103,
#  32108,
#  32105,
#  32138,
#  32107,
#  32108,
#  32107,
#  32139,
#  32105,
#  32140,
#  32125,
#  32141,
#  32114,
#  32142]
